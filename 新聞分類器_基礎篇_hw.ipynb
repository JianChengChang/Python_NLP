# %%
# !python --version
# Out:
# Python 3.7.6

# %%
# !pip install -q -U pip
# !pip install -q numpy
# !pip install -q pandas
# !pip install -q ckiptagger
# !pip install -q tqdm
# !pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('./data/')
pos = POS('./data/')
# Out:
# Exception ignored in: <function WS.__del__ at 0x000002ECC3457CA8>
# Traceback (most recent call last):
#   File "C:\Users\03950\Anaconda3\lib\site-packages\ckiptagger\api.py", line 65, in __del__
#     self.model.sess.close()
# AttributeError: 'WS' object has no attribute 'model'

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title])
    word_p = pos(word_s)
    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title])
    word_p = pos(word_s)
    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
# YOUR CODE HERE
n = 0
for index in train_title_cuts:
    for word, flag in train_title_cuts[index]:
        if word in word2index:
            continue
        word2index[word] = n
        index2word[n] = word
        n += 1
# END YOUR CODE

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    # YOUR CODE HERE
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index:
            vector[word2index[word]] += 1
    # END YOUR CODE
    return vector

# %%
get_bow_vector(train_title_cuts[0], word2index)
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['黃紫昌', '劉集', '堯治河', '朱之文', '卡帥', '萊昂納德', '騰訊王', '凱塔', '艷武漢', '高曉松', '大智慧', '姆巴佩', '韓長賦', '奧拉朱旺', '王楚欽', '拜仁', '安利', '榮威', '微博', 'S10', '萊科寧', '里皮', '賞月夜', '李', '海因克斯', '京新', '英超', '寶二', '楊帆', '郭煒煒', '馬龍', '馬化騰', '尼爾 ', '宇通', '人民日報', '游玄德', '埃米爾岡', '小詹皇', '姚振華', '董明珠', '鄭眼', '高通', '科勒·卡戴珊', '許昕', '惠若琪', '濃眉哥', '靜懿', '清華大學生', '哈登', '胤祥', '泰倫盧', '泰拳王西', '羅永浩', '馬克思', '詹', '馬內', '安靖', '美宇', '斯威', '余承東', '大神', '劉詩雯', '哪吒', '藍星', '海爾', '布茲德里克', '樊振東', '余小C', '宋清輝', '庫里', '扎哈維', '北京人和', '武當', '圍甲', '勒布朗詹姆斯', '郭春林', '王', '扎堆', '德安東尼', '埃梅里', '億航', '李大霄', '康德', '羅傑斯', '朱', '塔特姆', '遼足', '綠心', '神帥', '格力', '李暉', '聯盟里', '德羅贊', '電一', '海王星', '火箭隊', '昌圖', '卡拉斯科', '尤文', '易']
# =======================
# VC : ['誤判', '斬落', '捨棄', '摔', '反包', '指責', '撐', '毀滅', '找', '實行', '放', '發', '採取', '喜迎', '護送', '籌劃', '說動', '面對', '看多', '好', '完虐', '打爆', '實現', '認養', '接觸', '排', '兌換', '添脫', '打開', '抓', '扔上', '挖', '誘', '拉開', '學會', '買到', '完成', '開出', '挖出', '虛擬', '降', '待', '購買', '認可', '代替', '匯總', '擇', '用到', '打掃', '收穫', '獨造', '挑選出', '開啓', '共進', '結出', '欺騙', '管理', '幫助', '取', '制裁', '攀比', '看看', '爭', '領導', '製作', '套養', '對待', '誤觸', '構建', '評價', '炒作', '解讀', '對', '開好', '給出', '收到', '吃好', '獲取', '栽', '唱', '加強', '屠殺', '吹', '列', '重建', '下載', '起到', '發起', '賣出', '保護', '實拍', '發行', '分擔', '騎', '購置', '報', '種養', '取捨', '開', '經營']
# =======================
# Na : ['空氣', '黃葛樹', '獎金', '城市', '狗', '有效期', '懷化人', '狂魔', '季後賽', '香', '旅', '石油', '街鬥', '魔王', '獨生子女', '排行榜', '集團', '鬥戰神', '客服', '衣服', '男性', '黃龍火', '雨水', '蓮花', '湖南菜', '生死', '模式', '地球', '山坡', '風暴', '紅磚', '地貌', '開心果', '飛機', '地理', '管理', '級', '大掃帚', '場景', '管理層', '品質', '財富', '霸氣', '顧客', '可可', '岩漿', '奶媽', '絕壁', '父母', '七星級', '法網', '卡牌', '總決賽', '丁香花叢', '春季賽', '數字', '嚴寒期', '悲劇', '小花生', '經驗', '巷道', '風景', '名片', '狂言', '化肥會', '關稅', '代班門', '厚望', '力量', '借款', '商機', '大黃魚', '入圍賽', '水怪', '馬鈴薯', '節奏榜', '團體', '利潤', '區塊', '保障線', '搖籃', '米體', '秋光', '實用度', '活動', '出租車', '炭', '情報', '走勢', '葡萄', '光環', '房產證', '射手', '定存', '低頻', '酒糟', '大海', '線路', '紅險', '韓服王者']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['手游', '泰安', '城市', '尼泊爾', '高空', '呼倫貝爾', '山西', '小學', '行協', '沿線', '麗江', '工行', '孔子湖', '哈爾濱', '中科院', '瑞士', '溫州', '長沙', '俄羅斯', '京郊', '蒼穹', '朝邑鎮', '銀行', '上下游', '田野', '羅馬', '神壇', '果園', '大陸', '撫遠', '納米比亞', '牛場', '亞馬遜', '家', '亞索', '溫室', '茶館', '里貝里', '水果店', '九寨', '人區', '宅', '農場', '安徽', '伊朗', '吉隆坡', '北海地', '火鍋店', '陝西', '成中路', '袁家村', '鵬城', '紅河谷', '評論區', '華池縣', '遼寧', '內蒙古', '莊家', '韓國', '甘肅', '昆明', '便利店', '陷泥潭', '斯里蘭卡', '孟津', '舟山', '塔昌村', '情報站', '小丘鎮', '中國', '楚河', '皖南', '影視城', '附近', '景區', '馬刺', '德國', '縣里', '南半球', '保級區', '協會', '武林', '深海', '果嶺', '縣區', '市', '東京', '網站', '上位', '商鋪', '國安會', '杭州', '黃鶴樓', '北歐', '泰國', '沂水', '體育場', '拉薩', '火車站', '濱']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['罰款', '上架', '加持', '領銜', '提前', '入賬', '一網打盡', '分組', '開戰', '扣分', '應對', '充氣', '鍍金', '分紅', '加工', '解惑', '計算出來', '解圍', '加冕', '助威', '騙錢', '收回來', '護航', '加油', '充飢', '分段', '代打', '解密', '抓來', '融資', '導航', '效力', '通話', '退改', '退貨', '罵屌絲', '定位', '執教', '相比', '退款', '鋪平', '復仇', '站台', '拍照', '加起來', '解體', '再見']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['無可', '需', '一路', '不再', '經常', '居然', '能夠', '一手', '未', '白', '這麼', '接著', '逐漸', '差點兒', '沒有', '全力', '總算', '在', '略', '始', '絕', '本', '又', '盡情', '正在', '盡快', '並', '必', '再次', '絕對', '會不會', '全面', '簡直', '硬生生', '無法', '常常', '交互', '超級', '為什麼', '變相', '趕緊', '沒想到', '屢次', '應該', '相互', '實在', '不應該', '初', '陸續', '得', '怎樣', '全程', '越', '總會', '必須', '現', '率先', '快', '玩絕', '不', '老是', '微', '依然', '相', '皆', '好在', '怎麼', '互', '不可', '結伴', '連續', '多多', '難以', '該', '一直', '別', '一一', '為何', '連', '即', '急劇', '更', '會', '是否', '只是', '趁早', '親身', '趕快', '大都', '分別', '差點', '該不該', '可能', '要', '永', '新', '就', '不會', '不得', '仍']
# =======================
# P : ['因', '臨', '等', '隨', '幫', '向', '用', '比', '針對', '趁著', '到', '除了', '根據', '慘遭', '像', '自', '被', '距離', '在', '比如', '靠', '關於', '對', '往', '於', '當', '按', '以', '為了', '跟', '就', '除', '和', '至', '待', '直至', '給', '受', '從', '趁', '隨了', '自從', '將', '憑', '與', '遭', '如', '繼', '離', '為', '把']
# =======================
# VG : ['算', '當成', '成', '堪稱', '做成', '成為', '屬於', '集成', '猶如', '評選', '竟是', '名叫', '變成', '改造成', '稱作', '叫做', '像', '戰成', '投票成', '充當', '建成', '作為', '應聘', '理解為', '當上', '化', '並列', '排名', '美成', '稱得上', '排', '當作', '屈居', '封號', '算是', '排行', '類似', '當', '似', '等於', '酷似', '誤認成', '稱為', '疑似', '升任', '彷彿', '譽為', '居', '做', '合成', '形成', '賣成', '叫', '非', '姓', '變', '如', '為', '稱']
# =======================
# Neu : ['4.5億', '0-', '0:0', '70萬', '（二）', '一千', '135', '25', '392億', '第七', '百', '20億', '4萬多', '11', '4G+64', '175', '(00926)', '46萬', '6', '9-0', '1億', '56', '24億', '第33', '24.8億', '15.60', '3:1', ' 360', '2.5', '2599', '2000', '1200億', '萬億', '第1', '3000', '200', '千千萬', '9-1', '300萬', '0.2', '715', '1300', '980', '2400', '1.3萬', '8萬', '第五', '47', '百萬', '第四十四', '十萬', '38', '2018-05-06 ', '二十', '7000', '0', '5萬', '8', '1000萬', '2:3', '42', '21', '18', '2018', '11億', '7億', '180萬', '91', '300', '76', '1318', '12', '500萬', '三十', '60多', '2018.', 'b120', '1099', '7', '幾', '一500', '千億', '9', '1000', '甲', '22', '400', '30萬', '萬', '14', '第九', '10', '50多', '5.5', '4000萬', '十', '5.6千三', '1699', '3000萬', '十多萬']
# =======================
# Nf : ['盤', '隻', '股', '片', '頓', '米', '座', '度', '港元', '日', '輪', '層', '本', '槍', '位', '期', '袋', '週', '個', '句', '噸', '家', '局', '篇', '門', '歲', '級', '種', '些', '項', '道', '票', '英吋', '輛', '天', '碗', '對', '號', '類', '毛', '棵', '台', '串', '點', '周', '株', '張', '分鐘', '番', '支', '部', '節', '關', '件', '款', '秒', '名', '頁', '晚', '分', '公里', '次', '招', 'K', '處', '所', '步', '口', '斤', '遍', '塊', '戶', '畝', '胎', '則', '群', '路', '只', '屆', '檔', '刻', '美元', '元', '班', '鍋', '行', '筆', '批', '掛', '回', '頭', '套', '年', '條', '樣', '隊', '色', '把', '方', '場']
# =======================
# VJ : ['錯過', '缺', '含有', '強過', '限', '享受', '沒有', '靠', '達到', '不如', '懼怕', '熱心', '受到', '出於', '關注', '過完', '養有', '不到', '納入', '入圍', '超過', '獲得', '減持', '不敵', '欣賞', '缺少', '耗', '賽', '達', '逾', '得', '蘊藏', '適應', '晉級', '惹不起', '冷落', '從事', '喪失', '遭遇', '爆發', '遺傳', '近', '平', '自有', '優於', '懷念', '替代', '大勝', '來自', '贏得', '受', '獲', '沈迷', '充', '高達', '連接', '維持', '出', '珍惜', '衝', '降至', '嫌棄', '共享', '認', '惜', '曝限', '僅次於', '認識', '領略', '負', '緊缺', '透', '失', '煥發', '看好', '身臨', '順應', '出身', '歸屬於', '發生', '脫', '共有', '偏愛', '符合', '贊同', '要價', '獨佔', '虧損', '歸', '入選', '適用', '恭喜', '領先', '領跑', '抗', '贏下', '心疼', '震撼到', '忽略', '看懂']
# =======================
# VD : ['借', '清繳', '賣', '貸款', '給予', '禁售', '白送', '輸給', '借貸', '發', '配', '收費', '送', '拒賠', '贏', '搶', '傳', '寄予', '輸', '補繳', '速遞', '轉讓', '分', '還', '貸', '郵給', '補貼', '坑', '支付', '發放', '給', '供應', '欠', '售', '發給', '予', '付', '提供', '交付']
# =======================
# Dfa : ['如此', '遠遠', '有些', '極', '超', '更為', '多', '這麼', '非常', '十分', '越來越', '還要', '好', '不大', '頗', '較', '更', '太', '還', '過', '遠', '很', '有點', '過於', '最', '同樣', '比較']
# =======================
# VH : ['低迷', '相生', '收場', '夠', '恐怖', '成功', '為時已晚', '高開', '待機', '失落', '優越', '聰明', '倉促', '勝利', '欠佳', '清淨', '冒雨', '弱', '傳統', '好', '皆大歡喜', '無緣', '同步', '連勝', '風光', '平平無奇', '很多', '虐汪', '久', '不行', '下課', '合適', '投機', '上漲', '高度', '乾淨', '爆冷', '缺席', '呆滯', '黑', '智障', '遲滯', '發愁', '熱刺作死', '開啓', '出世', '眾包', '悠悠隆慶', '交融', '丟臉', '減產', '窮', '開花', '看呆', '霸氣', '好吃', '連續', '著急', '全自動', '恍然大悟', '混亂', '對', '正式', '另類', '濕潤', '新鮮', '辛酸', '隱蔽', '純淨', '成長', '暖', '史無前例', '神奇', '無望', '力輓狂瀾', '緊', '崛起', '分夠', '旺長', '可以', '如此', '對了', '大漲', '壯觀', '偉大', '漲停', '普通', '舊', '寬', '多彩', '真實', '客平人和', '稀少', '仿真', '夠多', '笨', '睡著', '破局', '和睦', '不同']
# =======================
# Cbb : ['因為', '因', '就算', '假如', '而是', '並且', '不過', '只要', '若', '不管', '否則', '跟著', '連', '既然', '但', '如果', '即使', '而', '不如', '另外', '並', '反而', '雖然', '要是', '縱使', '不然', '可是', '但是', '不僅', '只有', '既', '還不如']
# =======================
# Nd : ['明晚', '米節', '中旬', '週末', '季', '5日', '季度', '不久', '近日', '一下', '大中', '月季', '12日', '00年', '春天', '幾月份', '立夏', '隔年', '週二', '5.7日', '一會', '昔日', '2019年', '明日', '昨天', '秋季', '最後', '2005年', '後來', '長期', '三國', '6旬', '8月', '一日', '2018', '5月', '相親節', '下旬', '4日', '四月', '花季', '週一', '小時候', '當前', '早晨', '今夏', '今日', '2017年', '8日', '一大早', '半夜', '1點', '寒武紀', '2018年度', '31號', '現在', '19年', '當時', '周', '目前', '-5', '熱天', '夏窗', '後', '晚清', '15日', '七月份', '秋', '春', '未來', '30號', '3月', '7號', '荒古', '明', '同時', '夏天', '春季', '90年', '那時', '狗年', '九月', '23日', '05月', '五月份', '雍正', '過去', '夜', '5月份', '15年', '6月', '臨時', '文化節', '當年', '1990年', '後期', '何時', '初夏', '以後', '最近']
# =======================
# VA : ['回落', '旅遊', '代工', '擺地攤', '炒幣', '開門紅', '成交', '扣賬', '外出', '投訴', '看過來', '何去何從', '奔馳', '出貨', '出來', '擾民', '開團', '下班', '打麻將', '違規', '下山', '滑雪', '爭吵', '運營', '開啓', '摘帽', '亮相', '徵信', '醒', '倒流', '謝幕', '娶妻', '日落', '幹什麼', '脫貧', '下卡', '探界', '誕生', '刷單', '看盤', '問津', '偷鯤', '郊遊', '下雨', '打烊', '狩獵', '輪轉', '登場', '上場', '擒敵', '除權', '掃碼', '買單', '變通', '扶貧', '自駕', '上線', '升', '刮風', '釣魚', '種菜', '巡禮', '發家', '掃尾', '出國', '大小便', '拼房', '步行', '盤旋', '倒計', '助攻', '開票', '落地', '參賽', '來臨', '打工', '進城', '跳', '秋遊', '漂流', '退', '遠行', '變盤', '登高', '跌', '下降', '回家', '飆車', '減稅', '工作', '產仔', '生財', '鬥米', '相親', '奮鬥', '育秧', '掛機', '唱歌', '打卡', '炒房']
# =======================
# COMMACATEGORY : ['，', ',']
# =======================
# Nes : ['本', '上', '每', '近', '該', '下', '前', '貴', '何', '各', '某', '同', '後', '頭', '另', '首']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['！', '!']
# =======================
# Di : ['起來', '了', '著', '過', '個']
# =======================
# Nep : ['此', '這', '哪', '其', '其中', '啥', '什麼', '那']
# =======================
# Caa : ['又', '或', '還是', 'VS', '及', '與', '比', '跟', '至', '或是', '或者', '暨', '和', '到']
# =======================
# VCL : ['上', '玩遍', '前往', '遊覽', '走訪', '退出', '出發到', '栽進', '橫掃', '蒞臨', '去', '穿越', '重回', '到', '入', '升至', '走過', '走到', '回到', '在', '穿過', '重返', '前來', '路過', '登陸', '往', '到達', '直達', '走下', '進入', '過', '度過', '回', '住', '盤踞', '用於', '進', '暗渡', '深入', '穿透', '留在', '來到', '遠離', '跌出', '赴', '回歸', '出', '存進', '抵達', '跌至', '走進']
# =======================
# Neqa : ['90%', '一處處', '1/4', '一些', '15%', '大多', '80%', '有些', '三分之一', '全', '句句', '個個', '百分之八十', '所有', '多', '8%', '10%', '6%', '任何', '大多數', '9.89%', '67%', '一半', '一切', '100%', '步步', '許多', '這些', '很多', '不少', '30%', '1%', '這麼多', '12%', '多點', '其它', '20%', '有的', '其他', '那些', '部分', '41.8%', '更多', '一點', '半', '遍', '大量', '四成', '無數', '哪些', '多少', '滴滴', '0.8%']
# =======================
# Nh : ['大家', '雙方', '自身', '它', '各位', '屌絲', '他們', '自己', '誰', '別人', '你', '私人', '父子倆', '我們', '人家', '一方', '對方', '各自', '自我', '她們', '本人', '他', '小眾', '您', '我', '俺們', '它們', '你們', '她', '個人']
# =======================
# FW : ['Soloking', '：BTC', 'GPP', 'Pro', '6G', ' + ', 'iPhone X Plus', '！DOTA2 MOD', 'shou', 'app', '5G', 'Instagram', 'kpl', 'FPP', '丨', ' 比', 'GoogleI/O2018', 'ST', 'h', 'LOL', 'NPC', 'U23', 'QDC', 'note5', ' 28', 'Q', 'Mc', 'lol', 'ABCC', 'mc', 'CFO', 'AI', 'EOS', '+7', 'T+0', 'vip', 'AMD', 'S', 'J', 'Rookie', 'VR', 'mix2', '―', 'CBA', 'PS4/NS', 'C', 'QM', 'pro7', '：AG', 'Cotswolds', 'ADC', 'EVO', 'One', 'DW', ' VS ', 'X', '8d', 'l ', 'Uzi', 'CP', 'LOL：MSI', 'AWM', 'Rank', '/', 'Kakao', 'Ghappy', 'Aloha', 'e', '-6', 'AD', 'DNF：', 'lck', 'LPL', 'cosplay', '｜', 'HTC', 'PPP', 'N+1', 'OB', 'GDP', 'max2', 'CPI', 'VS', ' 2017', 'IOS', 'adc', 'Oeanc', 'iBoy', 'SSG', ' 秀', 'AIC', 'RPG', 'CCTV5', 'Brian Kelly', 'SIo', 'raid', 'iphone6plus', '~', '+4', 'UZI']
# =======================
# SHI : ['像是', '是']
# =======================
# VE : ['想到', '算', '公示', '提猜', '宣佈', '爆料', '講解', '看出', '精准', '研究', '賭約', '討說', '廣播', '限制', '揭曉', '以為', '知詢', '傳聞', '警惕', '防止', '檢測', '告訴', '介紹', '提起', '感嘆', '聽到', '申卡', '禁止', '猜', '判定', '探索', '識別', '聯想', '訴說', '看看', '反對', '報道', '回答', '查找', '商量', '披露', '聊', '管', '想起', '回顧', '要', '談', '預告', '提到', '暗示', '安排', '估值', '見', '承諾', '公認', '查看', '聽', '看清楚', '炫耀', '見證', '呼', '假設', '做到', '問', '確認', '盛贊', '鑒定', '查', '深思', '自嘲', '預防', '預測', '判斷', '發佈', '預計', '公佈', '提', '預期', '提醒', '設想', '認為', '抱怨', '預定', '允許', '樂見', '證', '想', '呼籲', '證明', '示範', '考慮', '看到', '探討', '說明', '聽說', '發現', '准', '公告', '形容', '講']
# =======================
# DE : ['之', '地', '得', '的']
# =======================
# VHC : ['結束', '陷', '溫暖', '愁死', '滿足', '公開', '斷', '規模化', '麻煩', '降低', '減少', '機構化', '加快', '凍', '擴張', '優化', '淡化', '告破', '辛苦', '現代化', '豐富', '停', '穩定', '下來', '平衡', '增強', '團結', '普及', '震驚', '縮小', '產生', '恢復', '傷', '增 ', '愁壞', '繁榮', '增長', '智能化', '強化', '冷卻', '感動', '熱', '還原', '增加', '破', '變動', '煩', '可憐', '暫停', '肥', '開', '壞', '國際化']
# =======================
# Ng : ['起', '上', '之間', '以來', '之內', '之外', '外', '以上', '以外', '來', '中', '間', '而言', '般', '裡', '底', '之下', '內', '下', '前', '之前', '左右', '以下', '之中', '時', '之上', '之後', '為止', '以後', '後', '初']
# =======================
# VK : ['不忘', '感受', '奇怪', '流傳', '需', '放心', '小心', '感覺', '介意', '面臨', '懂得', '注意', '欲', '知', '肯定', '意味', '抱歉', '忘', '理解', '感覺到', '討厭', '遺憾', '明白', '恨', '擔心', '意外', '堅持', '所謂', '瞭解', '願意', '想見', '願', '同意', '希望', '回憶', '信', '不滿', '懷疑', '期待', '曲解', '依賴', '確定', '感謝', '有利於', '遇', '懂', '喜歡', '盼', '指望', '需要', '顯示', '覺', '恐', '覺得', '意想不到', '怕', '忘記', '害怕', '知道']
# =======================
# Ncd : ['上', '兩旁', '哪裡', '裡面', '那邊', '東部', '上面', '東', '哪', '外', '前沿', '間', '中', '北', '哪兒', '裡', '內', '下', '當中', '西部', '對面', '這裡', '旁邊', '哪下', '外面', '邊', '中間', '西', '中部', '上方', '底部', '東西部', '那裡', '以下', '畔', '一帶', '東方', '末端', '方']
# =======================
# A : ['同等', '額外', '前置', '頭號', '長途', '上上', '雙', '優質', '同一', '眾', '超', '碧藍', '二手', '業餘', '單', '大幅度', '麻辣', '寶有', '新一代', '中', '總', '乒乓', '後置', '一般', '原', '必備', '唯一', '小本', '共同', '歐式', '彩色', '地下', '新興', '基礎', '獨門', '現行', '真正', '主', '火紅', '基層', '綜合', '現役', '高度', '超級', '多餘', '最佳', '常務', '野生', '重磅', '非', '獨角', '獨家', '中西', '國產']
# =======================
# V_2 : ['有']
# =======================
# VL : ['後悔', '使', '能', '故意', '開始', '致', '習慣', '用來', '肯', '令', '喜好', '便利', '甘願', '趨於', '讓', '不惜', '導致', '愛好', '敢', '持續', '使得', '愛']
# =======================
# T : ['咯', '吧', '的', '去', '哪', '嗎', '矣', '呢', '哦', '了', '來', '麼', '啊', '啦', '嘛']
# =======================
# VI : ['傾心', '取勝', '著稱', '驚艷', '專用']
# =======================
# DASHCATEGORY : ['-', '—']
# =======================
# I : ['瑪法里奧', '哦']
# =======================
# Dk : ['反過來', '那麼', '據聞', '外傳', '結果', '據說', '想不到', '那']
# =======================
# VF : ['策劃', '準備', '要求', '鼓勵', '推選', '申請', '繼續', '試試', '逼', '催', '打算', '擬', '勸說', '助', '率領', '試', '止住', '請', '帶領', '圖', '叫', '勸住', '停止', '拒絕', '告誡', '邀', '拒', '判']
# =======================
# Da : ['不下', '約', '唯獨', '足足', '最多', '近', '僅', '只', '幾近', '幾乎', '共', '將近', '光', '才', '正好']
# =======================
# PARENTHESISCATEGORY : ['）', '（', '「', '」', '》', '《', '(']
# =======================
# Nv : ['抗戰', '旅遊', '管理', '絕殺', '營銷', '增發', '經歷', '惡搞', '防治', '研究', '射擊', '問', '航海', '分銷', '生產', '買單', '關聯', '供電', '批發', '燃燒', '翻譯', '輔助', '銷售', '創業', '登山', '度假', '配置', '灌籃', '思考', '代理', '推薦', '解救', '疊加', '體驗', '判罰', '護髮', '開發', '崩潰', '私募', '遊樂', '組合', '兼職', '回歸', '錄制', '訴訟', '工作']
# =======================
# PERIODCATEGORY : ['。', '·']
# =======================
# VAC : ['推進', '集合', '移動', '上演', '蒸發', '動']
# =======================
# Dfb : ['一點', '極了', '些']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['以上', '多', '幾', '半']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        # YOUR CODE HERE
        'Nh', 'Nep', 'Nes', 'DE', 'T', 'P', 'V_2', 'SHI',
        'Dfa', 'Dfb', 'Da', 'Di', 'Dk',
        'Caa', 'Cab', 'Cba', 'Cbb',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
        # END YOUR CODE
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    # YOUR CODE HERE
    len1 = np.sqrt(np.sum(np.square(bow1)))
    len2 = np.sqrt(np.sum(np.square(bow2)))
    similarity = np.sum(bow1*bow2)/(len1*len2)
    # END YOUR CODE
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 73, '遊戲': 8, '財經': 6, '旅遊': 6, '農業': 6, '科技': 3})
# predict 財經 :  Counter({'財經': 67, '科技': 18, '體育': 6, '旅遊': 6, '遊戲': 6, '農業': 5})
# predict 科技 :  Counter({'科技': 62, '財經': 13, '體育': 10, '農業': 6, '遊戲': 6, '旅遊': 2})
# predict 旅遊 :  Counter({'旅遊': 70, '農業': 11, '財經': 6, '科技': 3, '遊戲': 2})
# predict 農業 :  Counter({'農業': 70, '旅遊': 9, '科技': 6, '體育': 5, '財經': 4, '遊戲': 3})
# predict 遊戲 :  Counter({'遊戲': 75, '科技': 7, '旅遊': 5, '體育': 4, '財經': 4, '農業': 1})
