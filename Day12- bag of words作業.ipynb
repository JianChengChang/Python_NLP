# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
nltk.download('punkt')
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\03950\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence.lower())
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2085個單字

# %%
whole_words
# Out:
# {'ample',
#  'maria',
#  'milk',
#  'bar',
#  'summary',
#  'rate',
#  'caught',
#  'wedges',
#  'eew',
#  'airline',
#  'simple',
#  'around',
#  'loves',
#  'gave',
#  'town',
#  'def',
#  'given',
#  'ice',
#  'besides',
#  'uploaded',
#  'longer',
#  'stomach',
#  'ians',
#  'spring',
#  'chef',
#  'sorely',
#  'insulted',
#  'ache',
#  'continue',
#  'server',
#  'living',
#  'devine',
#  'dish',
#  'trying',
#  'especially',
#  'before',
#  'chips',
#  'smashburger',
#  'expected',
#  'creamy',
#  'concept',
#  'passed',
#  'since',
#  'common',
#  'spends',
#  'lover',
#  'songs',
#  'neat',
#  'decorated',
#  "'re",
#  'wow',
#  'flavored',
#  'damn',
#  'ambience',
#  'almost',
#  'talk',
#  'double',
#  'gone',
#  'las',
#  'lemon',
#  'table',
#  'papers',
#  'sat',
#  'blandest',
#  'they',
#  'fear',
#  'yama',
#  'delightful',
#  'medium',
#  'below',
#  'pan',
#  'blown',
#  'wife',
#  'mozzarella',
#  'phoenix',
#  'plater',
#  'bagels',
#  'indoor',
#  'host',
#  'dealing',
#  'now',
#  'works',
#  'missing',
#  'sub-par',
#  'wayyy',
#  'madhouse',
#  'leaves',
#  'like',
#  'had',
#  'succulent',
#  'crepe',
#  'omg',
#  'bitches',
#  'corn',
#  'friends',
#  'brushfire',
#  'never',
#  'editing',
#  'themselves',
#  'martini',
#  "'",
#  'replenished',
#  'three',
#  'wienerschnitzel',
#  'lil',
#  'experiencing',
#  'pears',
#  'teamwork',
#  'cheap',
#  '..there',
#  'bite',
#  'gluten',
#  'tasteless',
#  'cotta',
#  'flavors',
#  'quite',
#  'perhaps',
#  'incredibly',
#  'full',
#  'couple',
#  'italian',
#  'tapas',
#  'omelets',
#  'sit-down',
#  'ever',
#  'car',
#  'soggy',
#  'refrained',
#  'doing',
#  'angry',
#  'slices',
#  'chow',
#  "'m",
#  'owner',
#  'regular',
#  'bisque',
#  'boiled',
#  'each',
#  'gringos',
#  'transcendant',
#  'eve',
#  'considering',
#  'side',
#  'kid',
#  'first',
#  'took',
#  'turkey',
#  'whatsoever',
#  'blue',
#  'meal',
#  'breaks',
#  'duo',
#  'waiting',
#  'email',
#  'presentation',
#  'call',
#  'hawaiian',
#  'moz',
#  'ayce',
#  'hell',
#  'hurry',
#  'gross',
#  'wasted',
#  'spices',
#  'bug',
#  'occasions',
#  'screwed',
#  'temp.i',
#  'casino',
#  'famous',
#  '100',
#  'fantastic',
#  'voodoo',
#  'take',
#  'duck',
#  'in',
#  'acknowledged',
#  'yeah',
#  'bakery',
#  'pasta',
#  'expect',
#  'wagyu',
#  'live',
#  'polite',
#  'find',
#  'opened',
#  'managed',
#  'wine',
#  'well',
#  'trap',
#  'ignored',
#  'eggplant',
#  'problem',
#  'warm',
#  'several',
#  'sucker',
#  'fav',
#  'although',
#  'cost',
#  ':',
#  'meat',
#  '2',
#  'last',
#  'hungry',
#  'google',
#  'nasty',
#  'five',
#  'accomodate',
#  'magic',
#  'con',
#  'hostess',
#  'buldogis',
#  'customers',
#  'placed',
#  'glad',
#  'filling',
#  'multiple',
#  'ethic',
#  'pastry',
#  'patron',
#  'boba',
#  'putting',
#  'steiners',
#  'caring',
#  'smeared',
#  'haunt',
#  'night',
#  'section',
#  'closed',
#  'menus',
#  'poorly',
#  'sitting',
#  'starving',
#  'hole',
#  'binge',
#  'expectations',
#  'freezing',
#  'hopes',
#  'cooking',
#  'everything',
#  'classics',
#  'our',
#  'gooodd',
#  'stretch',
#  'reheated',
#  'relleno',
#  'delight',
#  'outshining',
#  'provided',
#  'basically',
#  'waitress',
#  'does',
#  'reading',
#  'guacamole',
#  'dreamed',
#  'remember',
#  'circumstances',
#  'happier',
#  'priced',
#  'chip',
#  'honest',
#  'elegantly',
#  'greedy',
#  'deal',
#  'pancakes',
#  'blame',
#  'paying',
#  'coupons',
#  'compliments',
#  'tell',
#  'more',
#  'solid',
#  'exceptional',
#  'dog',
#  'cartel',
#  'tasted',
#  'despite',
#  'enough',
#  'business',
#  'tables',
#  'combination',
#  'golden-crispy',
#  'then',
#  'bodes',
#  'traditional',
#  'tough',
#  'market',
#  'fella',
#  'carly',
#  'upgrading',
#  'poisoning',
#  'jenni',
#  'changing',
#  "'d",
#  'shop',
#  'fruit',
#  'loving',
#  'panna',
#  'sour',
#  'approval',
#  'crawfish',
#  'hate',
#  'cut',
#  'reasonable',
#  'holiday',
#  'husband',
#  'unsatisfying',
#  'perfection',
#  'spicy',
#  '?',
#  'price',
#  'barely',
#  'gourmet',
#  'nutshell',
#  'mostly',
#  'frozen',
#  'hut',
#  'unless',
#  'madison',
#  'flavourful',
#  'including',
#  'nan',
#  'later',
#  'beyond',
#  'expert/connisseur',
#  'legs',
#  'nice',
#  'swung',
#  'food/service',
#  'thinly',
#  'anyone',
#  'choux',
#  'dressed',
#  'grandmother',
#  'seems',
#  'salad',
#  'condiment',
#  '.off',
#  'nargile',
#  'ala',
#  '40',
#  'reservation',
#  'suck',
#  "'ll",
#  'outstanding',
#  'airport',
#  'taco',
#  'many',
#  'lordy',
#  'funny',
#  'anytime',
#  '4.00',
#  'potato',
#  'prime',
#  'constructed',
#  'disappointed',
#  'nude',
#  'rapidly',
#  'ones',
#  'read',
#  'raspberry',
#  'cod',
#  'drinks',
#  'return',
#  'during',
#  'by',
#  'regularly',
#  'sangria',
#  'club',
#  'wrong',
#  'friendly',
#  'served',
#  'honestly',
#  'serivce',
#  'officially',
#  'bread',
#  'almonds',
#  'dont',
#  'tiny',
#  'used',
#  'yucky',
#  'twice',
#  'healthy',
#  'ripped',
#  'worst/annoying',
#  'as',
#  '-',
#  'desired',
#  'watch',
#  'forth',
#  'someone',
#  'usual',
#  'needless',
#  'accordingly',
#  'venue',
#  'those',
#  'massive',
#  'stale',
#  'soundtrack',
#  'strange',
#  'unique',
#  'my',
#  'shirt',
#  'highlight',
#  'short',
#  'paradise',
#  'describing',
#  'been-stepped-in-and-tracked-everywhere',
#  'is',
#  'maybe',
#  'spotty',
#  'customer',
#  'stepped',
#  'point',
#  'cow',
#  'gets',
#  'beans',
#  'muffin',
#  'sals',
#  'burgers',
#  'actually',
#  'cash',
#  'easily',
#  'douchey',
#  ',',
#  'vodka',
#  'toast',
#  'atrocious',
#  'mind',
#  'drinking',
#  'absolutely',
#  'has',
#  'typical',
#  'disappointing',
#  'pleasure',
#  'lacked',
#  'getting',
#  'recommend',
#  'stuff',
#  'miss',
#  '%',
#  'soooooo',
#  'worth',
#  '-drinks',
#  'lightly',
#  'quickly',
#  'tragedy',
#  'over-priced',
#  'positive',
#  'crumby',
#  'tacos',
#  'smooth',
#  'tolerance',
#  'give',
#  'girlfriend',
#  'vibe',
#  'offers',
#  'guests',
#  'owners',
#  'profiterole',
#  'atmosphere.1',
#  'disgusted',
#  'unbelievable',
#  'lighting',
#  'hereas',
#  'pile',
#  'non-fancy',
#  'classic',
#  'mortified',
#  'be',
#  'guest',
#  'somewhat',
#  'and',
#  'couples',
#  'spots',
#  'prepared',
#  'sashimi',
#  'highlights',
#  'spice',
#  'min',
#  'bamboo',
#  'today',
#  'figured',
#  'employee',
#  'rarely',
#  'strings',
#  'loved',
#  'court',
#  'so',
#  'on',
#  'dropped',
#  'seasonal',
#  'after',
#  'also',
#  'tomato',
#  'hard',
#  'risotto',
#  'cart',
#  'otto',
#  'dedicated',
#  'smoothies',
#  'vain',
#  'whole',
#  'become',
#  'set',
#  'piece',
#  'lacking',
#  'fry',
#  'bruschetta',
#  'space',
#  'one',
#  'surprise',
#  'style',
#  'back',
#  'cant',
#  'fail',
#  'crab',
#  'block',
#  'beauty',
#  'attached',
#  'went',
#  'opportunity',
#  'hilarious',
#  'pepper',
#  'chocolate',
#  'party',
#  'ignore',
#  'chinese',
#  'flop',
#  'have',
#  'dusted',
#  'teeth',
#  'prefer',
#  'occasional',
#  'humiliated',
#  'saving',
#  'relax',
#  'reminds',
#  'breeze',
#  'dirty',
#  'attack',
#  'sunday',
#  'hi',
#  'beer',
#  'inconsiderate',
#  'tribute',
#  'shoe',
#  'grab',
#  'screams',
#  'summarize',
#  'rare',
#  'doubt',
#  'dinners',
#  'unprofessional',
#  'saying',
#  'felt',
#  'fresh',
#  'taste',
#  'things',
#  'trips',
#  'falling',
#  'metro',
#  'avoid',
#  'english',
#  'part',
#  'its',
#  'satisfying',
#  '7.85',
#  'ordered',
#  'places',
#  'reasons',
#  'second',
#  'café',
#  'mango',
#  'az',
#  'do',
#  'based',
#  'probably',
#  "'s",
#  'accountant',
#  'wound',
#  'baseball',
#  'excellent',
#  'others',
#  'potatoes',
#  'disgust',
#  'update',
#  'sporting',
#  'folks',
#  'none',
#  'average',
#  'downright',
#  'gyro',
#  'show',
#  'for',
#  'bartender',
#  'refused',
#  'events',
#  'pack',
#  'guy',
#  'flavorful',
#  'pork',
#  'pink',
#  'help',
#  'delish',
#  'dos',
#  'fridays',
#  'claimed',
#  'toro',
#  '45',
#  'visited',
#  'eaten',
#  'thin',
#  'yellow',
#  'choose',
#  'cheeseburger',
#  'believe',
#  'seating',
#  'rated',
#  'just',
#  'disrespected',
#  'warnings',
#  'service-check',
#  'life',
#  'dispenser',
#  'hiro',
#  'fact',
#  'forgetting',
#  'bunch',
#  'delicate',
#  'waited',
#  'frenchman',
#  'pneumatic',
#  'ambiance',
#  'trimmed',
#  'vegetables',
#  'anything',
#  'article',
#  'piano',
#  'lighter',
#  'brick',
#  'jeff',
#  'hour',
#  'platter',
#  'walked',
#  '.way',
#  'location',
#  'meet',
#  'fuzzy',
#  'steakhouse',
#  'pecan',
#  'affordable',
#  'number',
#  'else',
#  'valley',
#  'unhealthy',
#  'were',
#  'auju',
#  'chai',
#  'workers',
#  'huge',
#  'drunk',
#  'tender',
#  'extensive',
#  'happened',
#  'boys',
#  'avoided',
#  'yet',
#  'middle',
#  'ways',
#  'violinists',
#  'mary',
#  'assure',
#  'him',
#  'scottsdale',
#  'everyone',
#  'judging',
#  'deliver',
#  'pub',
#  'alone',
#  '..ohhh',
#  'bone',
#  'meats',
#  '15',
#  'pricing',
#  'flower',
#  'did',
#  'fell',
#  'interesting',
#  'promise',
#  '10',
#  'unreal',
#  'pepper..and',
#  'croutons',
#  'drawing',
#  'mesquite',
#  'grocery',
#  'totally',
#  'tailored',
#  'opinion',
#  'ensued',
#  'boring',
#  'anyway',
#  'pulled',
#  'mess',
#  'neighborhood',
#  'rubber',
#  'businesses',
#  'winner',
#  'favor',
#  'ninja',
#  'khao',
#  'enjoyed',
#  'offered',
#  'callings',
#  'heard',
#  'gratitude',
#  'francisco',
#  'mouths',
#  'mediterranean',
#  'enjoyable',
#  'event',
#  'are',
#  'phenomenal',
#  'die',
#  'patty',
#  'been',
#  'promptly',
#  'that',
#  'recommending',
#  '7',
#  'vinaigrette',
#  'their',
#  'will',
#  'chefs',
#  'impressed',
#  'north',
#  'via',
#  'crema',
#  'sick',
#  'word',
#  'excalibur',
#  'charming',
#  'hot',
#  'most',
#  'customize',
#  'fair',
#  'joint',
#  'mention',
#  'found',
#  'guess',
#  'colder',
#  "'ve",
#  'ribeye',
#  'heat',
#  'hunan',
#  'front',
#  'establishment',
#  'hooked',
#  'flair',
#  'sprouts',
#  'very',
#  'chickens',
#  'really',
#  'chicken',
#  'imagined',
#  'simply',
#  'app',
#  'biggest',
#  'flirting',
#  'cannoli',
#  '...',
#  'inside',
#  'unwelcome',
#  'lost',
#  'cake',
#  'vomited',
#  'owned',
#  'bother',
#  'butter',
#  'done',
#  'station',
#  'play',
#  'mgm',
#  'ended',
#  'patio',
#  'quick',
#  'hardly',
#  'understand',
#  'mexican',
#  'old',
#  'hankering',
#  'may',
#  'would',
#  'break',
#  'want',
#  'crowds',
#  'shots',
#  'fast',
#  'decision',
#  'gyros',
#  'absolute',
#  'familiar',
#  'fluffy',
#  'warmer',
#  'tucson',
#  'similar',
#  'them',
#  'literally',
#  'containers',
#  'effort',
#  'stinks',
#  'sergeant',
#  'finally',
#  'greek',
#  'preparing',
#  'noodles',
#  'theft',
#  'shops',
#  'appealing',
#  'cover',
#  'wide',
#  'fine',
#  'gc',
#  "n't",
#  'wonderful',
#  '$',
#  'cramming',
#  'shall',
#  'decide',
#  'big',
#  'comfortable',
#  'selections',
#  'voted',
#  'rowdy',
#  'please',
#  'exceeding',
#  'generic',
#  'otherwise',
#  'eat',
#  'running',
#  'diverse',
#  'sugary',
#  'time',
#  'free',
#  'can',
#  'seat',
#  'jewel',
#  'friend',
#  'deeply',
#  'ago',
#  's',
#  'cool',
#  '3/4ths',
#  'oil',
#  'apparently',
#  'nothing',
#  'milkshake',
#  'bill',
#  'cashier',
#  'noca',
#  'care',
#  'forty',
#  'music',
#  'contain',
#  '5',
#  'thus',
#  'efficient',
#  'door',
#  'larger',
#  'eclectic',
#  'use',
#  'specials',
#  'iced',
#  'who',
#  'foot',
#  'unexperienced',
#  'peach',
#  'anymore',
#  'filet',
#  'try',
#  'mac',
#  'afternoon',
#  'liking',
#  'maintaining',
#  'slow',
#  'sushi',
#  'mean',
#  'deep',
#  'something',
#  'round',
#  'capers',
#  'hearts',
#  'seal',
#  'sense',
#  'crispy',
#  'employees',
#  '&',
#  'delivery',
#  'toasted',
#  'without',
#  'weak',
#  'bland',
#  'needs',
#  'roasted',
#  'coziness',
#  'out',
#  'lovely',
#  'performed',
#  'bucks',
#  'crostini',
#  'bare',
#  'ranch',
#  'bellagio',
#  'guys',
#  'high',
#  'clue',
#  'tonight',
#  'cashew',
#  'ri',
#  'experienced',
#  "''",
#  'overall',
#  'disapppointment',
#  'definitely',
#  'tenders',
#  'cream',
#  'fabulous',
#  'liked',
#  'his',
#  'lack',
#  'anyways',
#  'trippy',
#  'eel',
#  'andddd',
#  'correction',
#  'disgraceful',
#  'pricey',
#  'ask',
#  'welcome',
#  'batter',
#  'disagree',
#  'if',
#  'avocado',
#  'myself',
#  'judge',
#  'extraordinary',
#  'worst',
#  'genuinely',
#  'pumpkin',
#  'seen',
#  'wash',
#  'bought',
#  'which',
#  'zero',
#  'mediocre',
#  'rinse',
#  'crystals',
#  'parents',
#  '30s',
#  'scene',
#  'this',
#  'charged',
#  'bit',
#  'less',
#  'of',
#  'family',
#  'sauces',
#  'covered',
#  '4',
#  'spicier',
#  'asked',
#  'exquisite',
#  'ratio',
#  'sadly',
#  'seasoning',
#  'tummy',
#  'under-services',
#  'few',
#  'tepid',
#  'steaks',
#  'same',
#  'rick',
#  'fill',
#  'handed',
#  'says',
#  'tops',
#  'some',
#  'experience',
#  'either',
#  "ya'all",
#  'steak',
#  'elsewhere',
#  'good',
#  'bacon',
#  'self',
#  'disaster',
#  'letting',
#  'denny',
#  '10+',
#  ...}

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    index_word[n] = word
    n += 1

# %%
word_index
# Out:
# {'ample': 0,
#  'maria': 1,
#  'milk': 2,
#  'bar': 3,
#  'summary': 4,
#  'rate': 5,
#  'caught': 6,
#  'wedges': 7,
#  'eew': 8,
#  'airline': 9,
#  'simple': 10,
#  'around': 11,
#  'loves': 12,
#  'gave': 13,
#  'town': 14,
#  'def': 15,
#  'given': 16,
#  'ice': 17,
#  'besides': 18,
#  'uploaded': 19,
#  'longer': 20,
#  'stomach': 21,
#  'ians': 22,
#  'spring': 23,
#  'chef': 24,
#  'sorely': 25,
#  'insulted': 26,
#  'ache': 27,
#  'continue': 28,
#  'server': 29,
#  'living': 30,
#  'devine': 31,
#  'dish': 32,
#  'trying': 33,
#  'especially': 34,
#  'before': 35,
#  'chips': 36,
#  'smashburger': 37,
#  'expected': 38,
#  'creamy': 39,
#  'concept': 40,
#  'passed': 41,
#  'since': 42,
#  'common': 43,
#  'spends': 44,
#  'lover': 45,
#  'songs': 46,
#  'neat': 47,
#  'decorated': 48,
#  "'re": 49,
#  'wow': 50,
#  'flavored': 51,
#  'damn': 52,
#  'ambience': 53,
#  'almost': 54,
#  'talk': 55,
#  'double': 56,
#  'gone': 57,
#  'las': 58,
#  'lemon': 59,
#  'table': 60,
#  'papers': 61,
#  'sat': 62,
#  'blandest': 63,
#  'they': 64,
#  'fear': 65,
#  'yama': 66,
#  'delightful': 67,
#  'medium': 68,
#  'below': 69,
#  'pan': 70,
#  'blown': 71,
#  'wife': 72,
#  'mozzarella': 73,
#  'phoenix': 74,
#  'plater': 75,
#  'bagels': 76,
#  'indoor': 77,
#  'host': 78,
#  'dealing': 79,
#  'now': 80,
#  'works': 81,
#  'missing': 82,
#  'sub-par': 83,
#  'wayyy': 84,
#  'madhouse': 85,
#  'leaves': 86,
#  'like': 87,
#  'had': 88,
#  'succulent': 89,
#  'crepe': 90,
#  'omg': 91,
#  'bitches': 92,
#  'corn': 93,
#  'friends': 94,
#  'brushfire': 95,
#  'never': 96,
#  'editing': 97,
#  'themselves': 98,
#  'martini': 99,
#  "'": 100,
#  'replenished': 101,
#  'three': 102,
#  'wienerschnitzel': 103,
#  'lil': 104,
#  'experiencing': 105,
#  'pears': 106,
#  'teamwork': 107,
#  'cheap': 108,
#  '..there': 109,
#  'bite': 110,
#  'gluten': 111,
#  'tasteless': 112,
#  'cotta': 113,
#  'flavors': 114,
#  'quite': 115,
#  'perhaps': 116,
#  'incredibly': 117,
#  'full': 118,
#  'couple': 119,
#  'italian': 120,
#  'tapas': 121,
#  'omelets': 122,
#  'sit-down': 123,
#  'ever': 124,
#  'car': 125,
#  'soggy': 126,
#  'refrained': 127,
#  'doing': 128,
#  'angry': 129,
#  'slices': 130,
#  'chow': 131,
#  "'m": 132,
#  'owner': 133,
#  'regular': 134,
#  'bisque': 135,
#  'boiled': 136,
#  'each': 137,
#  'gringos': 138,
#  'transcendant': 139,
#  'eve': 140,
#  'considering': 141,
#  'side': 142,
#  'kid': 143,
#  'first': 144,
#  'took': 145,
#  'turkey': 146,
#  'whatsoever': 147,
#  'blue': 148,
#  'meal': 149,
#  'breaks': 150,
#  'duo': 151,
#  'waiting': 152,
#  'email': 153,
#  'presentation': 154,
#  'call': 155,
#  'hawaiian': 156,
#  'moz': 157,
#  'ayce': 158,
#  'hell': 159,
#  'hurry': 160,
#  'gross': 161,
#  'wasted': 162,
#  'spices': 163,
#  'bug': 164,
#  'occasions': 165,
#  'screwed': 166,
#  'temp.i': 167,
#  'casino': 168,
#  'famous': 169,
#  '100': 170,
#  'fantastic': 171,
#  'voodoo': 172,
#  'take': 173,
#  'duck': 174,
#  'in': 175,
#  'acknowledged': 176,
#  'yeah': 177,
#  'bakery': 178,
#  'pasta': 179,
#  'expect': 180,
#  'wagyu': 181,
#  'live': 182,
#  'polite': 183,
#  'find': 184,
#  'opened': 185,
#  'managed': 186,
#  'wine': 187,
#  'well': 188,
#  'trap': 189,
#  'ignored': 190,
#  'eggplant': 191,
#  'problem': 192,
#  'warm': 193,
#  'several': 194,
#  'sucker': 195,
#  'fav': 196,
#  'although': 197,
#  'cost': 198,
#  ':': 199,
#  'meat': 200,
#  '2': 201,
#  'last': 202,
#  'hungry': 203,
#  'google': 204,
#  'nasty': 205,
#  'five': 206,
#  'accomodate': 207,
#  'magic': 208,
#  'con': 209,
#  'hostess': 210,
#  'buldogis': 211,
#  'customers': 212,
#  'placed': 213,
#  'glad': 214,
#  'filling': 215,
#  'multiple': 216,
#  'ethic': 217,
#  'pastry': 218,
#  'patron': 219,
#  'boba': 220,
#  'putting': 221,
#  'steiners': 222,
#  'caring': 223,
#  'smeared': 224,
#  'haunt': 225,
#  'night': 226,
#  'section': 227,
#  'closed': 228,
#  'menus': 229,
#  'poorly': 230,
#  'sitting': 231,
#  'starving': 232,
#  'hole': 233,
#  'binge': 234,
#  'expectations': 235,
#  'freezing': 236,
#  'hopes': 237,
#  'cooking': 238,
#  'everything': 239,
#  'classics': 240,
#  'our': 241,
#  'gooodd': 242,
#  'stretch': 243,
#  'reheated': 244,
#  'relleno': 245,
#  'delight': 246,
#  'outshining': 247,
#  'provided': 248,
#  'basically': 249,
#  'waitress': 250,
#  'does': 251,
#  'reading': 252,
#  'guacamole': 253,
#  'dreamed': 254,
#  'remember': 255,
#  'circumstances': 256,
#  'happier': 257,
#  'priced': 258,
#  'chip': 259,
#  'honest': 260,
#  'elegantly': 261,
#  'greedy': 262,
#  'deal': 263,
#  'pancakes': 264,
#  'blame': 265,
#  'paying': 266,
#  'coupons': 267,
#  'compliments': 268,
#  'tell': 269,
#  'more': 270,
#  'solid': 271,
#  'exceptional': 272,
#  'dog': 273,
#  'cartel': 274,
#  'tasted': 275,
#  'despite': 276,
#  'enough': 277,
#  'business': 278,
#  'tables': 279,
#  'combination': 280,
#  'golden-crispy': 281,
#  'then': 282,
#  'bodes': 283,
#  'traditional': 284,
#  'tough': 285,
#  'market': 286,
#  'fella': 287,
#  'carly': 288,
#  'upgrading': 289,
#  'poisoning': 290,
#  'jenni': 291,
#  'changing': 292,
#  "'d": 293,
#  'shop': 294,
#  'fruit': 295,
#  'loving': 296,
#  'panna': 297,
#  'sour': 298,
#  'approval': 299,
#  'crawfish': 300,
#  'hate': 301,
#  'cut': 302,
#  'reasonable': 303,
#  'holiday': 304,
#  'husband': 305,
#  'unsatisfying': 306,
#  'perfection': 307,
#  'spicy': 308,
#  '?': 309,
#  'price': 310,
#  'barely': 311,
#  'gourmet': 312,
#  'nutshell': 313,
#  'mostly': 314,
#  'frozen': 315,
#  'hut': 316,
#  'unless': 317,
#  'madison': 318,
#  'flavourful': 319,
#  'including': 320,
#  'nan': 321,
#  'later': 322,
#  'beyond': 323,
#  'expert/connisseur': 324,
#  'legs': 325,
#  'nice': 326,
#  'swung': 327,
#  'food/service': 328,
#  'thinly': 329,
#  'anyone': 330,
#  'choux': 331,
#  'dressed': 332,
#  'grandmother': 333,
#  'seems': 334,
#  'salad': 335,
#  'condiment': 336,
#  '.off': 337,
#  'nargile': 338,
#  'ala': 339,
#  '40': 340,
#  'reservation': 341,
#  'suck': 342,
#  "'ll": 343,
#  'outstanding': 344,
#  'airport': 345,
#  'taco': 346,
#  'many': 347,
#  'lordy': 348,
#  'funny': 349,
#  'anytime': 350,
#  '4.00': 351,
#  'potato': 352,
#  'prime': 353,
#  'constructed': 354,
#  'disappointed': 355,
#  'nude': 356,
#  'rapidly': 357,
#  'ones': 358,
#  'read': 359,
#  'raspberry': 360,
#  'cod': 361,
#  'drinks': 362,
#  'return': 363,
#  'during': 364,
#  'by': 365,
#  'regularly': 366,
#  'sangria': 367,
#  'club': 368,
#  'wrong': 369,
#  'friendly': 370,
#  'served': 371,
#  'honestly': 372,
#  'serivce': 373,
#  'officially': 374,
#  'bread': 375,
#  'almonds': 376,
#  'dont': 377,
#  'tiny': 378,
#  'used': 379,
#  'yucky': 380,
#  'twice': 381,
#  'healthy': 382,
#  'ripped': 383,
#  'worst/annoying': 384,
#  'as': 385,
#  '-': 386,
#  'desired': 387,
#  'watch': 388,
#  'forth': 389,
#  'someone': 390,
#  'usual': 391,
#  'needless': 392,
#  'accordingly': 393,
#  'venue': 394,
#  'those': 395,
#  'massive': 396,
#  'stale': 397,
#  'soundtrack': 398,
#  'strange': 399,
#  'unique': 400,
#  'my': 401,
#  'shirt': 402,
#  'highlight': 403,
#  'short': 404,
#  'paradise': 405,
#  'describing': 406,
#  'been-stepped-in-and-tracked-everywhere': 407,
#  'is': 408,
#  'maybe': 409,
#  'spotty': 410,
#  'customer': 411,
#  'stepped': 412,
#  'point': 413,
#  'cow': 414,
#  'gets': 415,
#  'beans': 416,
#  'muffin': 417,
#  'sals': 418,
#  'burgers': 419,
#  'actually': 420,
#  'cash': 421,
#  'easily': 422,
#  'douchey': 423,
#  ',': 424,
#  'vodka': 425,
#  'toast': 426,
#  'atrocious': 427,
#  'mind': 428,
#  'drinking': 429,
#  'absolutely': 430,
#  'has': 431,
#  'typical': 432,
#  'disappointing': 433,
#  'pleasure': 434,
#  'lacked': 435,
#  'getting': 436,
#  'recommend': 437,
#  'stuff': 438,
#  'miss': 439,
#  '%': 440,
#  'soooooo': 441,
#  'worth': 442,
#  '-drinks': 443,
#  'lightly': 444,
#  'quickly': 445,
#  'tragedy': 446,
#  'over-priced': 447,
#  'positive': 448,
#  'crumby': 449,
#  'tacos': 450,
#  'smooth': 451,
#  'tolerance': 452,
#  'give': 453,
#  'girlfriend': 454,
#  'vibe': 455,
#  'offers': 456,
#  'guests': 457,
#  'owners': 458,
#  'profiterole': 459,
#  'atmosphere.1': 460,
#  'disgusted': 461,
#  'unbelievable': 462,
#  'lighting': 463,
#  'hereas': 464,
#  'pile': 465,
#  'non-fancy': 466,
#  'classic': 467,
#  'mortified': 468,
#  'be': 469,
#  'guest': 470,
#  'somewhat': 471,
#  'and': 472,
#  'couples': 473,
#  'spots': 474,
#  'prepared': 475,
#  'sashimi': 476,
#  'highlights': 477,
#  'spice': 478,
#  'min': 479,
#  'bamboo': 480,
#  'today': 481,
#  'figured': 482,
#  'employee': 483,
#  'rarely': 484,
#  'strings': 485,
#  'loved': 486,
#  'court': 487,
#  'so': 488,
#  'on': 489,
#  'dropped': 490,
#  'seasonal': 491,
#  'after': 492,
#  'also': 493,
#  'tomato': 494,
#  'hard': 495,
#  'risotto': 496,
#  'cart': 497,
#  'otto': 498,
#  'dedicated': 499,
#  'smoothies': 500,
#  'vain': 501,
#  'whole': 502,
#  'become': 503,
#  'set': 504,
#  'piece': 505,
#  'lacking': 506,
#  'fry': 507,
#  'bruschetta': 508,
#  'space': 509,
#  'one': 510,
#  'surprise': 511,
#  'style': 512,
#  'back': 513,
#  'cant': 514,
#  'fail': 515,
#  'crab': 516,
#  'block': 517,
#  'beauty': 518,
#  'attached': 519,
#  'went': 520,
#  'opportunity': 521,
#  'hilarious': 522,
#  'pepper': 523,
#  'chocolate': 524,
#  'party': 525,
#  'ignore': 526,
#  'chinese': 527,
#  'flop': 528,
#  'have': 529,
#  'dusted': 530,
#  'teeth': 531,
#  'prefer': 532,
#  'occasional': 533,
#  'humiliated': 534,
#  'saving': 535,
#  'relax': 536,
#  'reminds': 537,
#  'breeze': 538,
#  'dirty': 539,
#  'attack': 540,
#  'sunday': 541,
#  'hi': 542,
#  'beer': 543,
#  'inconsiderate': 544,
#  'tribute': 545,
#  'shoe': 546,
#  'grab': 547,
#  'screams': 548,
#  'summarize': 549,
#  'rare': 550,
#  'doubt': 551,
#  'dinners': 552,
#  'unprofessional': 553,
#  'saying': 554,
#  'felt': 555,
#  'fresh': 556,
#  'taste': 557,
#  'things': 558,
#  'trips': 559,
#  'falling': 560,
#  'metro': 561,
#  'avoid': 562,
#  'english': 563,
#  'part': 564,
#  'its': 565,
#  'satisfying': 566,
#  '7.85': 567,
#  'ordered': 568,
#  'places': 569,
#  'reasons': 570,
#  'second': 571,
#  'café': 572,
#  'mango': 573,
#  'az': 574,
#  'do': 575,
#  'based': 576,
#  'probably': 577,
#  "'s": 578,
#  'accountant': 579,
#  'wound': 580,
#  'baseball': 581,
#  'excellent': 582,
#  'others': 583,
#  'potatoes': 584,
#  'disgust': 585,
#  'update': 586,
#  'sporting': 587,
#  'folks': 588,
#  'none': 589,
#  'average': 590,
#  'downright': 591,
#  'gyro': 592,
#  'show': 593,
#  'for': 594,
#  'bartender': 595,
#  'refused': 596,
#  'events': 597,
#  'pack': 598,
#  'guy': 599,
#  'flavorful': 600,
#  'pork': 601,
#  'pink': 602,
#  'help': 603,
#  'delish': 604,
#  'dos': 605,
#  'fridays': 606,
#  'claimed': 607,
#  'toro': 608,
#  '45': 609,
#  'visited': 610,
#  'eaten': 611,
#  'thin': 612,
#  'yellow': 613,
#  'choose': 614,
#  'cheeseburger': 615,
#  'believe': 616,
#  'seating': 617,
#  'rated': 618,
#  'just': 619,
#  'disrespected': 620,
#  'warnings': 621,
#  'service-check': 622,
#  'life': 623,
#  'dispenser': 624,
#  'hiro': 625,
#  'fact': 626,
#  'forgetting': 627,
#  'bunch': 628,
#  'delicate': 629,
#  'waited': 630,
#  'frenchman': 631,
#  'pneumatic': 632,
#  'ambiance': 633,
#  'trimmed': 634,
#  'vegetables': 635,
#  'anything': 636,
#  'article': 637,
#  'piano': 638,
#  'lighter': 639,
#  'brick': 640,
#  'jeff': 641,
#  'hour': 642,
#  'platter': 643,
#  'walked': 644,
#  '.way': 645,
#  'location': 646,
#  'meet': 647,
#  'fuzzy': 648,
#  'steakhouse': 649,
#  'pecan': 650,
#  'affordable': 651,
#  'number': 652,
#  'else': 653,
#  'valley': 654,
#  'unhealthy': 655,
#  'were': 656,
#  'auju': 657,
#  'chai': 658,
#  'workers': 659,
#  'huge': 660,
#  'drunk': 661,
#  'tender': 662,
#  'extensive': 663,
#  'happened': 664,
#  'boys': 665,
#  'avoided': 666,
#  'yet': 667,
#  'middle': 668,
#  'ways': 669,
#  'violinists': 670,
#  'mary': 671,
#  'assure': 672,
#  'him': 673,
#  'scottsdale': 674,
#  'everyone': 675,
#  'judging': 676,
#  'deliver': 677,
#  'pub': 678,
#  'alone': 679,
#  '..ohhh': 680,
#  'bone': 681,
#  'meats': 682,
#  '15': 683,
#  'pricing': 684,
#  'flower': 685,
#  'did': 686,
#  'fell': 687,
#  'interesting': 688,
#  'promise': 689,
#  '10': 690,
#  'unreal': 691,
#  'pepper..and': 692,
#  'croutons': 693,
#  'drawing': 694,
#  'mesquite': 695,
#  'grocery': 696,
#  'totally': 697,
#  'tailored': 698,
#  'opinion': 699,
#  'ensued': 700,
#  'boring': 701,
#  'anyway': 702,
#  'pulled': 703,
#  'mess': 704,
#  'neighborhood': 705,
#  'rubber': 706,
#  'businesses': 707,
#  'winner': 708,
#  'favor': 709,
#  'ninja': 710,
#  'khao': 711,
#  'enjoyed': 712,
#  'offered': 713,
#  'callings': 714,
#  'heard': 715,
#  'gratitude': 716,
#  'francisco': 717,
#  'mouths': 718,
#  'mediterranean': 719,
#  'enjoyable': 720,
#  'event': 721,
#  'are': 722,
#  'phenomenal': 723,
#  'die': 724,
#  'patty': 725,
#  'been': 726,
#  'promptly': 727,
#  'that': 728,
#  'recommending': 729,
#  '7': 730,
#  'vinaigrette': 731,
#  'their': 732,
#  'will': 733,
#  'chefs': 734,
#  'impressed': 735,
#  'north': 736,
#  'via': 737,
#  'crema': 738,
#  'sick': 739,
#  'word': 740,
#  'excalibur': 741,
#  'charming': 742,
#  'hot': 743,
#  'most': 744,
#  'customize': 745,
#  'fair': 746,
#  'joint': 747,
#  'mention': 748,
#  'found': 749,
#  'guess': 750,
#  'colder': 751,
#  "'ve": 752,
#  'ribeye': 753,
#  'heat': 754,
#  'hunan': 755,
#  'front': 756,
#  'establishment': 757,
#  'hooked': 758,
#  'flair': 759,
#  'sprouts': 760,
#  'very': 761,
#  'chickens': 762,
#  'really': 763,
#  'chicken': 764,
#  'imagined': 765,
#  'simply': 766,
#  'app': 767,
#  'biggest': 768,
#  'flirting': 769,
#  'cannoli': 770,
#  '...': 771,
#  'inside': 772,
#  'unwelcome': 773,
#  'lost': 774,
#  'cake': 775,
#  'vomited': 776,
#  'owned': 777,
#  'bother': 778,
#  'butter': 779,
#  'done': 780,
#  'station': 781,
#  'play': 782,
#  'mgm': 783,
#  'ended': 784,
#  'patio': 785,
#  'quick': 786,
#  'hardly': 787,
#  'understand': 788,
#  'mexican': 789,
#  'old': 790,
#  'hankering': 791,
#  'may': 792,
#  'would': 793,
#  'break': 794,
#  'want': 795,
#  'crowds': 796,
#  'shots': 797,
#  'fast': 798,
#  'decision': 799,
#  'gyros': 800,
#  'absolute': 801,
#  'familiar': 802,
#  'fluffy': 803,
#  'warmer': 804,
#  'tucson': 805,
#  'similar': 806,
#  'them': 807,
#  'literally': 808,
#  'containers': 809,
#  'effort': 810,
#  'stinks': 811,
#  'sergeant': 812,
#  'finally': 813,
#  'greek': 814,
#  'preparing': 815,
#  'noodles': 816,
#  'theft': 817,
#  'shops': 818,
#  'appealing': 819,
#  'cover': 820,
#  'wide': 821,
#  'fine': 822,
#  'gc': 823,
#  "n't": 824,
#  'wonderful': 825,
#  '$': 826,
#  'cramming': 827,
#  'shall': 828,
#  'decide': 829,
#  'big': 830,
#  'comfortable': 831,
#  'selections': 832,
#  'voted': 833,
#  'rowdy': 834,
#  'please': 835,
#  'exceeding': 836,
#  'generic': 837,
#  'otherwise': 838,
#  'eat': 839,
#  'running': 840,
#  'diverse': 841,
#  'sugary': 842,
#  'time': 843,
#  'free': 844,
#  'can': 845,
#  'seat': 846,
#  'jewel': 847,
#  'friend': 848,
#  'deeply': 849,
#  'ago': 850,
#  's': 851,
#  'cool': 852,
#  '3/4ths': 853,
#  'oil': 854,
#  'apparently': 855,
#  'nothing': 856,
#  'milkshake': 857,
#  'bill': 858,
#  'cashier': 859,
#  'noca': 860,
#  'care': 861,
#  'forty': 862,
#  'music': 863,
#  'contain': 864,
#  '5': 865,
#  'thus': 866,
#  'efficient': 867,
#  'door': 868,
#  'larger': 869,
#  'eclectic': 870,
#  'use': 871,
#  'specials': 872,
#  'iced': 873,
#  'who': 874,
#  'foot': 875,
#  'unexperienced': 876,
#  'peach': 877,
#  'anymore': 878,
#  'filet': 879,
#  'try': 880,
#  'mac': 881,
#  'afternoon': 882,
#  'liking': 883,
#  'maintaining': 884,
#  'slow': 885,
#  'sushi': 886,
#  'mean': 887,
#  'deep': 888,
#  'something': 889,
#  'round': 890,
#  'capers': 891,
#  'hearts': 892,
#  'seal': 893,
#  'sense': 894,
#  'crispy': 895,
#  'employees': 896,
#  '&': 897,
#  'delivery': 898,
#  'toasted': 899,
#  'without': 900,
#  'weak': 901,
#  'bland': 902,
#  'needs': 903,
#  'roasted': 904,
#  'coziness': 905,
#  'out': 906,
#  'lovely': 907,
#  'performed': 908,
#  'bucks': 909,
#  'crostini': 910,
#  'bare': 911,
#  'ranch': 912,
#  'bellagio': 913,
#  'guys': 914,
#  'high': 915,
#  'clue': 916,
#  'tonight': 917,
#  'cashew': 918,
#  'ri': 919,
#  'experienced': 920,
#  "''": 921,
#  'overall': 922,
#  'disapppointment': 923,
#  'definitely': 924,
#  'tenders': 925,
#  'cream': 926,
#  'fabulous': 927,
#  'liked': 928,
#  'his': 929,
#  'lack': 930,
#  'anyways': 931,
#  'trippy': 932,
#  'eel': 933,
#  'andddd': 934,
#  'correction': 935,
#  'disgraceful': 936,
#  'pricey': 937,
#  'ask': 938,
#  'welcome': 939,
#  'batter': 940,
#  'disagree': 941,
#  'if': 942,
#  'avocado': 943,
#  'myself': 944,
#  'judge': 945,
#  'extraordinary': 946,
#  'worst': 947,
#  'genuinely': 948,
#  'pumpkin': 949,
#  'seen': 950,
#  'wash': 951,
#  'bought': 952,
#  'which': 953,
#  'zero': 954,
#  'mediocre': 955,
#  'rinse': 956,
#  'crystals': 957,
#  'parents': 958,
#  '30s': 959,
#  'scene': 960,
#  'this': 961,
#  'charged': 962,
#  'bit': 963,
#  'less': 964,
#  'of': 965,
#  'family': 966,
#  'sauces': 967,
#  'covered': 968,
#  '4': 969,
#  'spicier': 970,
#  'asked': 971,
#  'exquisite': 972,
#  'ratio': 973,
#  'sadly': 974,
#  'seasoning': 975,
#  'tummy': 976,
#  'under-services': 977,
#  'few': 978,
#  'tepid': 979,
#  'steaks': 980,
#  'same': 981,
#  'rick': 982,
#  'fill': 983,
#  'handed': 984,
#  'says': 985,
#  'tops': 986,
#  'some': 987,
#  'experience': 988,
#  'either': 989,
#  "ya'all": 990,
#  'steak': 991,
#  'elsewhere': 992,
#  'good': 993,
#  'bacon': 994,
#  'self': 995,
#  'disaster': 996,
#  'letting': 997,
#  'denny': 998,
#  '10+': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'ample',
#  1: 'maria',
#  2: 'milk',
#  3: 'bar',
#  4: 'summary',
#  5: 'rate',
#  6: 'caught',
#  7: 'wedges',
#  8: 'eew',
#  9: 'airline',
#  10: 'simple',
#  11: 'around',
#  12: 'loves',
#  13: 'gave',
#  14: 'town',
#  15: 'def',
#  16: 'given',
#  17: 'ice',
#  18: 'besides',
#  19: 'uploaded',
#  20: 'longer',
#  21: 'stomach',
#  22: 'ians',
#  23: 'spring',
#  24: 'chef',
#  25: 'sorely',
#  26: 'insulted',
#  27: 'ache',
#  28: 'continue',
#  29: 'server',
#  30: 'living',
#  31: 'devine',
#  32: 'dish',
#  33: 'trying',
#  34: 'especially',
#  35: 'before',
#  36: 'chips',
#  37: 'smashburger',
#  38: 'expected',
#  39: 'creamy',
#  40: 'concept',
#  41: 'passed',
#  42: 'since',
#  43: 'common',
#  44: 'spends',
#  45: 'lover',
#  46: 'songs',
#  47: 'neat',
#  48: 'decorated',
#  49: "'re",
#  50: 'wow',
#  51: 'flavored',
#  52: 'damn',
#  53: 'ambience',
#  54: 'almost',
#  55: 'talk',
#  56: 'double',
#  57: 'gone',
#  58: 'las',
#  59: 'lemon',
#  60: 'table',
#  61: 'papers',
#  62: 'sat',
#  63: 'blandest',
#  64: 'they',
#  65: 'fear',
#  66: 'yama',
#  67: 'delightful',
#  68: 'medium',
#  69: 'below',
#  70: 'pan',
#  71: 'blown',
#  72: 'wife',
#  73: 'mozzarella',
#  74: 'phoenix',
#  75: 'plater',
#  76: 'bagels',
#  77: 'indoor',
#  78: 'host',
#  79: 'dealing',
#  80: 'now',
#  81: 'works',
#  82: 'missing',
#  83: 'sub-par',
#  84: 'wayyy',
#  85: 'madhouse',
#  86: 'leaves',
#  87: 'like',
#  88: 'had',
#  89: 'succulent',
#  90: 'crepe',
#  91: 'omg',
#  92: 'bitches',
#  93: 'corn',
#  94: 'friends',
#  95: 'brushfire',
#  96: 'never',
#  97: 'editing',
#  98: 'themselves',
#  99: 'martini',
#  100: "'",
#  101: 'replenished',
#  102: 'three',
#  103: 'wienerschnitzel',
#  104: 'lil',
#  105: 'experiencing',
#  106: 'pears',
#  107: 'teamwork',
#  108: 'cheap',
#  109: '..there',
#  110: 'bite',
#  111: 'gluten',
#  112: 'tasteless',
#  113: 'cotta',
#  114: 'flavors',
#  115: 'quite',
#  116: 'perhaps',
#  117: 'incredibly',
#  118: 'full',
#  119: 'couple',
#  120: 'italian',
#  121: 'tapas',
#  122: 'omelets',
#  123: 'sit-down',
#  124: 'ever',
#  125: 'car',
#  126: 'soggy',
#  127: 'refrained',
#  128: 'doing',
#  129: 'angry',
#  130: 'slices',
#  131: 'chow',
#  132: "'m",
#  133: 'owner',
#  134: 'regular',
#  135: 'bisque',
#  136: 'boiled',
#  137: 'each',
#  138: 'gringos',
#  139: 'transcendant',
#  140: 'eve',
#  141: 'considering',
#  142: 'side',
#  143: 'kid',
#  144: 'first',
#  145: 'took',
#  146: 'turkey',
#  147: 'whatsoever',
#  148: 'blue',
#  149: 'meal',
#  150: 'breaks',
#  151: 'duo',
#  152: 'waiting',
#  153: 'email',
#  154: 'presentation',
#  155: 'call',
#  156: 'hawaiian',
#  157: 'moz',
#  158: 'ayce',
#  159: 'hell',
#  160: 'hurry',
#  161: 'gross',
#  162: 'wasted',
#  163: 'spices',
#  164: 'bug',
#  165: 'occasions',
#  166: 'screwed',
#  167: 'temp.i',
#  168: 'casino',
#  169: 'famous',
#  170: '100',
#  171: 'fantastic',
#  172: 'voodoo',
#  173: 'take',
#  174: 'duck',
#  175: 'in',
#  176: 'acknowledged',
#  177: 'yeah',
#  178: 'bakery',
#  179: 'pasta',
#  180: 'expect',
#  181: 'wagyu',
#  182: 'live',
#  183: 'polite',
#  184: 'find',
#  185: 'opened',
#  186: 'managed',
#  187: 'wine',
#  188: 'well',
#  189: 'trap',
#  190: 'ignored',
#  191: 'eggplant',
#  192: 'problem',
#  193: 'warm',
#  194: 'several',
#  195: 'sucker',
#  196: 'fav',
#  197: 'although',
#  198: 'cost',
#  199: ':',
#  200: 'meat',
#  201: '2',
#  202: 'last',
#  203: 'hungry',
#  204: 'google',
#  205: 'nasty',
#  206: 'five',
#  207: 'accomodate',
#  208: 'magic',
#  209: 'con',
#  210: 'hostess',
#  211: 'buldogis',
#  212: 'customers',
#  213: 'placed',
#  214: 'glad',
#  215: 'filling',
#  216: 'multiple',
#  217: 'ethic',
#  218: 'pastry',
#  219: 'patron',
#  220: 'boba',
#  221: 'putting',
#  222: 'steiners',
#  223: 'caring',
#  224: 'smeared',
#  225: 'haunt',
#  226: 'night',
#  227: 'section',
#  228: 'closed',
#  229: 'menus',
#  230: 'poorly',
#  231: 'sitting',
#  232: 'starving',
#  233: 'hole',
#  234: 'binge',
#  235: 'expectations',
#  236: 'freezing',
#  237: 'hopes',
#  238: 'cooking',
#  239: 'everything',
#  240: 'classics',
#  241: 'our',
#  242: 'gooodd',
#  243: 'stretch',
#  244: 'reheated',
#  245: 'relleno',
#  246: 'delight',
#  247: 'outshining',
#  248: 'provided',
#  249: 'basically',
#  250: 'waitress',
#  251: 'does',
#  252: 'reading',
#  253: 'guacamole',
#  254: 'dreamed',
#  255: 'remember',
#  256: 'circumstances',
#  257: 'happier',
#  258: 'priced',
#  259: 'chip',
#  260: 'honest',
#  261: 'elegantly',
#  262: 'greedy',
#  263: 'deal',
#  264: 'pancakes',
#  265: 'blame',
#  266: 'paying',
#  267: 'coupons',
#  268: 'compliments',
#  269: 'tell',
#  270: 'more',
#  271: 'solid',
#  272: 'exceptional',
#  273: 'dog',
#  274: 'cartel',
#  275: 'tasted',
#  276: 'despite',
#  277: 'enough',
#  278: 'business',
#  279: 'tables',
#  280: 'combination',
#  281: 'golden-crispy',
#  282: 'then',
#  283: 'bodes',
#  284: 'traditional',
#  285: 'tough',
#  286: 'market',
#  287: 'fella',
#  288: 'carly',
#  289: 'upgrading',
#  290: 'poisoning',
#  291: 'jenni',
#  292: 'changing',
#  293: "'d",
#  294: 'shop',
#  295: 'fruit',
#  296: 'loving',
#  297: 'panna',
#  298: 'sour',
#  299: 'approval',
#  300: 'crawfish',
#  301: 'hate',
#  302: 'cut',
#  303: 'reasonable',
#  304: 'holiday',
#  305: 'husband',
#  306: 'unsatisfying',
#  307: 'perfection',
#  308: 'spicy',
#  309: '?',
#  310: 'price',
#  311: 'barely',
#  312: 'gourmet',
#  313: 'nutshell',
#  314: 'mostly',
#  315: 'frozen',
#  316: 'hut',
#  317: 'unless',
#  318: 'madison',
#  319: 'flavourful',
#  320: 'including',
#  321: 'nan',
#  322: 'later',
#  323: 'beyond',
#  324: 'expert/connisseur',
#  325: 'legs',
#  326: 'nice',
#  327: 'swung',
#  328: 'food/service',
#  329: 'thinly',
#  330: 'anyone',
#  331: 'choux',
#  332: 'dressed',
#  333: 'grandmother',
#  334: 'seems',
#  335: 'salad',
#  336: 'condiment',
#  337: '.off',
#  338: 'nargile',
#  339: 'ala',
#  340: '40',
#  341: 'reservation',
#  342: 'suck',
#  343: "'ll",
#  344: 'outstanding',
#  345: 'airport',
#  346: 'taco',
#  347: 'many',
#  348: 'lordy',
#  349: 'funny',
#  350: 'anytime',
#  351: '4.00',
#  352: 'potato',
#  353: 'prime',
#  354: 'constructed',
#  355: 'disappointed',
#  356: 'nude',
#  357: 'rapidly',
#  358: 'ones',
#  359: 'read',
#  360: 'raspberry',
#  361: 'cod',
#  362: 'drinks',
#  363: 'return',
#  364: 'during',
#  365: 'by',
#  366: 'regularly',
#  367: 'sangria',
#  368: 'club',
#  369: 'wrong',
#  370: 'friendly',
#  371: 'served',
#  372: 'honestly',
#  373: 'serivce',
#  374: 'officially',
#  375: 'bread',
#  376: 'almonds',
#  377: 'dont',
#  378: 'tiny',
#  379: 'used',
#  380: 'yucky',
#  381: 'twice',
#  382: 'healthy',
#  383: 'ripped',
#  384: 'worst/annoying',
#  385: 'as',
#  386: '-',
#  387: 'desired',
#  388: 'watch',
#  389: 'forth',
#  390: 'someone',
#  391: 'usual',
#  392: 'needless',
#  393: 'accordingly',
#  394: 'venue',
#  395: 'those',
#  396: 'massive',
#  397: 'stale',
#  398: 'soundtrack',
#  399: 'strange',
#  400: 'unique',
#  401: 'my',
#  402: 'shirt',
#  403: 'highlight',
#  404: 'short',
#  405: 'paradise',
#  406: 'describing',
#  407: 'been-stepped-in-and-tracked-everywhere',
#  408: 'is',
#  409: 'maybe',
#  410: 'spotty',
#  411: 'customer',
#  412: 'stepped',
#  413: 'point',
#  414: 'cow',
#  415: 'gets',
#  416: 'beans',
#  417: 'muffin',
#  418: 'sals',
#  419: 'burgers',
#  420: 'actually',
#  421: 'cash',
#  422: 'easily',
#  423: 'douchey',
#  424: ',',
#  425: 'vodka',
#  426: 'toast',
#  427: 'atrocious',
#  428: 'mind',
#  429: 'drinking',
#  430: 'absolutely',
#  431: 'has',
#  432: 'typical',
#  433: 'disappointing',
#  434: 'pleasure',
#  435: 'lacked',
#  436: 'getting',
#  437: 'recommend',
#  438: 'stuff',
#  439: 'miss',
#  440: '%',
#  441: 'soooooo',
#  442: 'worth',
#  443: '-drinks',
#  444: 'lightly',
#  445: 'quickly',
#  446: 'tragedy',
#  447: 'over-priced',
#  448: 'positive',
#  449: 'crumby',
#  450: 'tacos',
#  451: 'smooth',
#  452: 'tolerance',
#  453: 'give',
#  454: 'girlfriend',
#  455: 'vibe',
#  456: 'offers',
#  457: 'guests',
#  458: 'owners',
#  459: 'profiterole',
#  460: 'atmosphere.1',
#  461: 'disgusted',
#  462: 'unbelievable',
#  463: 'lighting',
#  464: 'hereas',
#  465: 'pile',
#  466: 'non-fancy',
#  467: 'classic',
#  468: 'mortified',
#  469: 'be',
#  470: 'guest',
#  471: 'somewhat',
#  472: 'and',
#  473: 'couples',
#  474: 'spots',
#  475: 'prepared',
#  476: 'sashimi',
#  477: 'highlights',
#  478: 'spice',
#  479: 'min',
#  480: 'bamboo',
#  481: 'today',
#  482: 'figured',
#  483: 'employee',
#  484: 'rarely',
#  485: 'strings',
#  486: 'loved',
#  487: 'court',
#  488: 'so',
#  489: 'on',
#  490: 'dropped',
#  491: 'seasonal',
#  492: 'after',
#  493: 'also',
#  494: 'tomato',
#  495: 'hard',
#  496: 'risotto',
#  497: 'cart',
#  498: 'otto',
#  499: 'dedicated',
#  500: 'smoothies',
#  501: 'vain',
#  502: 'whole',
#  503: 'become',
#  504: 'set',
#  505: 'piece',
#  506: 'lacking',
#  507: 'fry',
#  508: 'bruschetta',
#  509: 'space',
#  510: 'one',
#  511: 'surprise',
#  512: 'style',
#  513: 'back',
#  514: 'cant',
#  515: 'fail',
#  516: 'crab',
#  517: 'block',
#  518: 'beauty',
#  519: 'attached',
#  520: 'went',
#  521: 'opportunity',
#  522: 'hilarious',
#  523: 'pepper',
#  524: 'chocolate',
#  525: 'party',
#  526: 'ignore',
#  527: 'chinese',
#  528: 'flop',
#  529: 'have',
#  530: 'dusted',
#  531: 'teeth',
#  532: 'prefer',
#  533: 'occasional',
#  534: 'humiliated',
#  535: 'saving',
#  536: 'relax',
#  537: 'reminds',
#  538: 'breeze',
#  539: 'dirty',
#  540: 'attack',
#  541: 'sunday',
#  542: 'hi',
#  543: 'beer',
#  544: 'inconsiderate',
#  545: 'tribute',
#  546: 'shoe',
#  547: 'grab',
#  548: 'screams',
#  549: 'summarize',
#  550: 'rare',
#  551: 'doubt',
#  552: 'dinners',
#  553: 'unprofessional',
#  554: 'saying',
#  555: 'felt',
#  556: 'fresh',
#  557: 'taste',
#  558: 'things',
#  559: 'trips',
#  560: 'falling',
#  561: 'metro',
#  562: 'avoid',
#  563: 'english',
#  564: 'part',
#  565: 'its',
#  566: 'satisfying',
#  567: '7.85',
#  568: 'ordered',
#  569: 'places',
#  570: 'reasons',
#  571: 'second',
#  572: 'café',
#  573: 'mango',
#  574: 'az',
#  575: 'do',
#  576: 'based',
#  577: 'probably',
#  578: "'s",
#  579: 'accountant',
#  580: 'wound',
#  581: 'baseball',
#  582: 'excellent',
#  583: 'others',
#  584: 'potatoes',
#  585: 'disgust',
#  586: 'update',
#  587: 'sporting',
#  588: 'folks',
#  589: 'none',
#  590: 'average',
#  591: 'downright',
#  592: 'gyro',
#  593: 'show',
#  594: 'for',
#  595: 'bartender',
#  596: 'refused',
#  597: 'events',
#  598: 'pack',
#  599: 'guy',
#  600: 'flavorful',
#  601: 'pork',
#  602: 'pink',
#  603: 'help',
#  604: 'delish',
#  605: 'dos',
#  606: 'fridays',
#  607: 'claimed',
#  608: 'toro',
#  609: '45',
#  610: 'visited',
#  611: 'eaten',
#  612: 'thin',
#  613: 'yellow',
#  614: 'choose',
#  615: 'cheeseburger',
#  616: 'believe',
#  617: 'seating',
#  618: 'rated',
#  619: 'just',
#  620: 'disrespected',
#  621: 'warnings',
#  622: 'service-check',
#  623: 'life',
#  624: 'dispenser',
#  625: 'hiro',
#  626: 'fact',
#  627: 'forgetting',
#  628: 'bunch',
#  629: 'delicate',
#  630: 'waited',
#  631: 'frenchman',
#  632: 'pneumatic',
#  633: 'ambiance',
#  634: 'trimmed',
#  635: 'vegetables',
#  636: 'anything',
#  637: 'article',
#  638: 'piano',
#  639: 'lighter',
#  640: 'brick',
#  641: 'jeff',
#  642: 'hour',
#  643: 'platter',
#  644: 'walked',
#  645: '.way',
#  646: 'location',
#  647: 'meet',
#  648: 'fuzzy',
#  649: 'steakhouse',
#  650: 'pecan',
#  651: 'affordable',
#  652: 'number',
#  653: 'else',
#  654: 'valley',
#  655: 'unhealthy',
#  656: 'were',
#  657: 'auju',
#  658: 'chai',
#  659: 'workers',
#  660: 'huge',
#  661: 'drunk',
#  662: 'tender',
#  663: 'extensive',
#  664: 'happened',
#  665: 'boys',
#  666: 'avoided',
#  667: 'yet',
#  668: 'middle',
#  669: 'ways',
#  670: 'violinists',
#  671: 'mary',
#  672: 'assure',
#  673: 'him',
#  674: 'scottsdale',
#  675: 'everyone',
#  676: 'judging',
#  677: 'deliver',
#  678: 'pub',
#  679: 'alone',
#  680: '..ohhh',
#  681: 'bone',
#  682: 'meats',
#  683: '15',
#  684: 'pricing',
#  685: 'flower',
#  686: 'did',
#  687: 'fell',
#  688: 'interesting',
#  689: 'promise',
#  690: '10',
#  691: 'unreal',
#  692: 'pepper..and',
#  693: 'croutons',
#  694: 'drawing',
#  695: 'mesquite',
#  696: 'grocery',
#  697: 'totally',
#  698: 'tailored',
#  699: 'opinion',
#  700: 'ensued',
#  701: 'boring',
#  702: 'anyway',
#  703: 'pulled',
#  704: 'mess',
#  705: 'neighborhood',
#  706: 'rubber',
#  707: 'businesses',
#  708: 'winner',
#  709: 'favor',
#  710: 'ninja',
#  711: 'khao',
#  712: 'enjoyed',
#  713: 'offered',
#  714: 'callings',
#  715: 'heard',
#  716: 'gratitude',
#  717: 'francisco',
#  718: 'mouths',
#  719: 'mediterranean',
#  720: 'enjoyable',
#  721: 'event',
#  722: 'are',
#  723: 'phenomenal',
#  724: 'die',
#  725: 'patty',
#  726: 'been',
#  727: 'promptly',
#  728: 'that',
#  729: 'recommending',
#  730: '7',
#  731: 'vinaigrette',
#  732: 'their',
#  733: 'will',
#  734: 'chefs',
#  735: 'impressed',
#  736: 'north',
#  737: 'via',
#  738: 'crema',
#  739: 'sick',
#  740: 'word',
#  741: 'excalibur',
#  742: 'charming',
#  743: 'hot',
#  744: 'most',
#  745: 'customize',
#  746: 'fair',
#  747: 'joint',
#  748: 'mention',
#  749: 'found',
#  750: 'guess',
#  751: 'colder',
#  752: "'ve",
#  753: 'ribeye',
#  754: 'heat',
#  755: 'hunan',
#  756: 'front',
#  757: 'establishment',
#  758: 'hooked',
#  759: 'flair',
#  760: 'sprouts',
#  761: 'very',
#  762: 'chickens',
#  763: 'really',
#  764: 'chicken',
#  765: 'imagined',
#  766: 'simply',
#  767: 'app',
#  768: 'biggest',
#  769: 'flirting',
#  770: 'cannoli',
#  771: '...',
#  772: 'inside',
#  773: 'unwelcome',
#  774: 'lost',
#  775: 'cake',
#  776: 'vomited',
#  777: 'owned',
#  778: 'bother',
#  779: 'butter',
#  780: 'done',
#  781: 'station',
#  782: 'play',
#  783: 'mgm',
#  784: 'ended',
#  785: 'patio',
#  786: 'quick',
#  787: 'hardly',
#  788: 'understand',
#  789: 'mexican',
#  790: 'old',
#  791: 'hankering',
#  792: 'may',
#  793: 'would',
#  794: 'break',
#  795: 'want',
#  796: 'crowds',
#  797: 'shots',
#  798: 'fast',
#  799: 'decision',
#  800: 'gyros',
#  801: 'absolute',
#  802: 'familiar',
#  803: 'fluffy',
#  804: 'warmer',
#  805: 'tucson',
#  806: 'similar',
#  807: 'them',
#  808: 'literally',
#  809: 'containers',
#  810: 'effort',
#  811: 'stinks',
#  812: 'sergeant',
#  813: 'finally',
#  814: 'greek',
#  815: 'preparing',
#  816: 'noodles',
#  817: 'theft',
#  818: 'shops',
#  819: 'appealing',
#  820: 'cover',
#  821: 'wide',
#  822: 'fine',
#  823: 'gc',
#  824: "n't",
#  825: 'wonderful',
#  826: '$',
#  827: 'cramming',
#  828: 'shall',
#  829: 'decide',
#  830: 'big',
#  831: 'comfortable',
#  832: 'selections',
#  833: 'voted',
#  834: 'rowdy',
#  835: 'please',
#  836: 'exceeding',
#  837: 'generic',
#  838: 'otherwise',
#  839: 'eat',
#  840: 'running',
#  841: 'diverse',
#  842: 'sugary',
#  843: 'time',
#  844: 'free',
#  845: 'can',
#  846: 'seat',
#  847: 'jewel',
#  848: 'friend',
#  849: 'deeply',
#  850: 'ago',
#  851: 's',
#  852: 'cool',
#  853: '3/4ths',
#  854: 'oil',
#  855: 'apparently',
#  856: 'nothing',
#  857: 'milkshake',
#  858: 'bill',
#  859: 'cashier',
#  860: 'noca',
#  861: 'care',
#  862: 'forty',
#  863: 'music',
#  864: 'contain',
#  865: '5',
#  866: 'thus',
#  867: 'efficient',
#  868: 'door',
#  869: 'larger',
#  870: 'eclectic',
#  871: 'use',
#  872: 'specials',
#  873: 'iced',
#  874: 'who',
#  875: 'foot',
#  876: 'unexperienced',
#  877: 'peach',
#  878: 'anymore',
#  879: 'filet',
#  880: 'try',
#  881: 'mac',
#  882: 'afternoon',
#  883: 'liking',
#  884: 'maintaining',
#  885: 'slow',
#  886: 'sushi',
#  887: 'mean',
#  888: 'deep',
#  889: 'something',
#  890: 'round',
#  891: 'capers',
#  892: 'hearts',
#  893: 'seal',
#  894: 'sense',
#  895: 'crispy',
#  896: 'employees',
#  897: '&',
#  898: 'delivery',
#  899: 'toasted',
#  900: 'without',
#  901: 'weak',
#  902: 'bland',
#  903: 'needs',
#  904: 'roasted',
#  905: 'coziness',
#  906: 'out',
#  907: 'lovely',
#  908: 'performed',
#  909: 'bucks',
#  910: 'crostini',
#  911: 'bare',
#  912: 'ranch',
#  913: 'bellagio',
#  914: 'guys',
#  915: 'high',
#  916: 'clue',
#  917: 'tonight',
#  918: 'cashew',
#  919: 'ri',
#  920: 'experienced',
#  921: "''",
#  922: 'overall',
#  923: 'disapppointment',
#  924: 'definitely',
#  925: 'tenders',
#  926: 'cream',
#  927: 'fabulous',
#  928: 'liked',
#  929: 'his',
#  930: 'lack',
#  931: 'anyways',
#  932: 'trippy',
#  933: 'eel',
#  934: 'andddd',
#  935: 'correction',
#  936: 'disgraceful',
#  937: 'pricey',
#  938: 'ask',
#  939: 'welcome',
#  940: 'batter',
#  941: 'disagree',
#  942: 'if',
#  943: 'avocado',
#  944: 'myself',
#  945: 'judge',
#  946: 'extraordinary',
#  947: 'worst',
#  948: 'genuinely',
#  949: 'pumpkin',
#  950: 'seen',
#  951: 'wash',
#  952: 'bought',
#  953: 'which',
#  954: 'zero',
#  955: 'mediocre',
#  956: 'rinse',
#  957: 'crystals',
#  958: 'parents',
#  959: '30s',
#  960: 'scene',
#  961: 'this',
#  962: 'charged',
#  963: 'bit',
#  964: 'less',
#  965: 'of',
#  966: 'family',
#  967: 'sauces',
#  968: 'covered',
#  969: '4',
#  970: 'spicier',
#  971: 'asked',
#  972: 'exquisite',
#  973: 'ratio',
#  974: 'sadly',
#  975: 'seasoning',
#  976: 'tummy',
#  977: 'under-services',
#  978: 'few',
#  979: 'tepid',
#  980: 'steaks',
#  981: 'same',
#  982: 'rick',
#  983: 'fill',
#  984: 'handed',
#  985: 'says',
#  986: 'tops',
#  987: 'some',
#  988: 'experience',
#  989: 'either',
#  990: "ya'all",
#  991: 'steak',
#  992: 'elsewhere',
#  993: 'good',
#  994: 'bacon',
#  995: 'self',
#  996: 'disaster',
#  997: 'letting',
#  998: 'denny',
#  999: '10+',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow...I love the place'.lower(), word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
