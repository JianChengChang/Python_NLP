# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
nltk.download('punkt')
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\03950\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %%
whole_words
# Out:
# {'Will',
#  'Frozen',
#  'milk',
#  'bar',
#  'summary',
#  'rate',
#  'caught',
#  'wedges',
#  'airline',
#  'simple',
#  'Gold',
#  'around',
#  'loves',
#  'gave',
#  'town',
#  'given',
#  'ice',
#  'AVOID',
#  'Seat',
#  'besides',
#  'uploaded',
#  'longer',
#  'stomach',
#  'Hut',
#  'sorely',
#  'spring',
#  'chef',
#  'insulted',
#  'ache',
#  'continue',
#  'server',
#  'living',
#  'devine',
#  'dish',
#  'trying',
#  'FANTASTIC',
#  'especially',
#  'Coffee',
#  'before',
#  'BITCHES',
#  'Sour',
#  'chips',
#  'expected',
#  'creamy',
#  'Ians',
#  'concept',
#  'passed',
#  'since',
#  'common',
#  'spends',
#  'Waited',
#  'lover',
#  'songs',
#  'neat',
#  'decorated',
#  'Overpriced',
#  "'re",
#  'flavored',
#  'wow',
#  'damn',
#  'On',
#  'ambience',
#  'almost',
#  'talk',
#  'double',
#  'Sadly',
#  'gone',
#  'table',
#  'papers',
#  'sat',
#  'blandest',
#  'they',
#  'fear',
#  'delightful',
#  'medium',
#  'below',
#  'pan',
#  'blown',
#  'wife',
#  'mozzarella',
#  'Bellagio',
#  'bagels',
#  'Cant',
#  'Khao',
#  'indoor',
#  'Thoroughly',
#  'Love',
#  'Avoid',
#  'dealing',
#  'now',
#  'works',
#  'missing',
#  'Not',
#  'wayyy',
#  'sub-par',
#  'madhouse',
#  'leaves',
#  'like',
#  'had',
#  'succulent',
#  'crepe',
#  'corn',
#  'One',
#  'THAT',
#  'friends',
#  'never',
#  'editing',
#  'themselves',
#  'martini',
#  "'",
#  'replenished',
#  'three',
#  'lil',
#  'Vegas',
#  'experiencing',
#  'pears',
#  'teamwork',
#  'cheap',
#  '..there',
#  'bite',
#  'gluten',
#  'tasteless',
#  'Steiners',
#  'flavors',
#  'Thai',
#  'quite',
#  'incredibly',
#  'full',
#  'couple',
#  'Smashburger',
#  'tapas',
#  'sit-down',
#  'ever',
#  'car',
#  'soggy',
#  'refrained',
#  'doing',
#  'An',
#  'angry',
#  'slices',
#  'chow',
#  "'m",
#  'owner',
#  'regular',
#  'Plater',
#  'When',
#  'boiled',
#  'NASTY',
#  'each',
#  'transcendant',
#  'Wonderful',
#  'considering',
#  'side',
#  'kid',
#  'first',
#  'BACK',
#  'Casino',
#  'Vegetarian',
#  'took',
#  'turkey',
#  'whatsoever',
#  'blue',
#  'Dog',
#  'meal',
#  'breaks',
#  'duo',
#  'waiting',
#  'email',
#  'presentation',
#  'call',
#  'moz',
#  'Those',
#  'hurry',
#  'gross',
#  'Big',
#  'Update',
#  'wasted',
#  'spices',
#  'bug',
#  'occasions',
#  'Nothing',
#  'screwed',
#  'famous',
#  '100',
#  'fantastic',
#  'take',
#  'High-quality',
#  'duck',
#  'me..Bunch',
#  'in',
#  'acknowledged',
#  'bakery',
#  'UNREAL',
#  'pasta',
#  'North',
#  'expect',
#  'wagyu',
#  'live',
#  'polite',
#  'Mandalay',
#  'find',
#  'Heimer',
#  'opened',
#  'managed',
#  'Left',
#  'wine',
#  'well',
#  'Spend',
#  'Disappointing',
#  'trap',
#  'ignored',
#  'eggplant',
#  'Honestly',
#  'May',
#  'warm',
#  'several',
#  'problem',
#  '.THE',
#  'sucker',
#  'Plus',
#  'fav',
#  'although',
#  'cost',
#  ':',
#  'Main',
#  'meat',
#  '2',
#  'last',
#  'hungry',
#  'Shrimp-',
#  'nasty',
#  'five',
#  'accomodate',
#  'Taco',
#  'Kids',
#  'hostess',
#  'customers',
#  'placed',
#  'glad',
#  'filling',
#  'multiple',
#  'ethic',
#  'pastry',
#  'ESTABLISHMENT',
#  'Anyway',
#  'Sooooo',
#  'patron',
#  'boba',
#  'putting',
#  'caring',
#  'smeared',
#  'Ganoush',
#  'Salad',
#  'haunt',
#  'TV',
#  'night',
#  'section',
#  'closed',
#  'menus',
#  'poorly',
#  'sitting',
#  'starving',
#  'hole',
#  'binge',
#  'expectations',
#  'hopes',
#  'HOUR',
#  'cooking',
#  'everything',
#  'classics',
#  'Horrible',
#  'our',
#  'gooodd',
#  'Mary',
#  'Despite',
#  'stretch',
#  'reheated',
#  'relleno',
#  'delight',
#  'outshining',
#  'provided',
#  'basically',
#  'waitress',
#  'does',
#  'reading',
#  'guacamole',
#  'dreamed',
#  'remember',
#  'circumstances',
#  'happier',
#  'BARE',
#  'priced',
#  'Pretty',
#  'WASTE',
#  'chip',
#  'Maria',
#  'Always',
#  'honest',
#  'elegantly',
#  'greedy',
#  'deal',
#  'NONE',
#  'pancakes',
#  'blame',
#  'coupons',
#  'compliments',
#  'tell',
#  'Standard',
#  'more',
#  'Crema',
#  'solid',
#  'exceptional',
#  'dog',
#  'tasted',
#  'enough',
#  'business',
#  'tables',
#  'combination',
#  'golden-crispy',
#  'then',
#  'They',
#  'bodes',
#  'traditional',
#  'tough',
#  'market',
#  'fella',
#  'upgrading',
#  'Cotta',
#  'Appetite',
#  'Based',
#  'poisoning',
#  'Fridays',
#  'changing',
#  "'d",
#  'fruit',
#  'Everything',
#  'loving',
#  'approval',
#  'crawfish',
#  'hate',
#  'cut',
#  'reasonable',
#  'MGM',
#  'holiday',
#  'husband',
#  'Yelpers',
#  'Hunan',
#  'unsatisfying',
#  'perfection',
#  'spicy',
#  '?',
#  'price',
#  'barely',
#  'Took',
#  'nutshell',
#  'mostly',
#  'A',
#  'frozen',
#  'Company',
#  'unless',
#  'Tucson',
#  'flavourful',
#  'including',
#  'later',
#  'beyond',
#  'Must',
#  'expert/connisseur',
#  'legs',
#  'nice',
#  'swung',
#  'food/service',
#  'thinly',
#  'anyone',
#  'choux',
#  'dressed',
#  'grandmother',
#  'seems',
#  'salad',
#  'Awful',
#  'condiment',
#  '.off',
#  'ala',
#  '40',
#  'Eclectic',
#  'Check',
#  'reservation',
#  'suck',
#  "'ll",
#  'outstanding',
#  'airport',
#  'taco',
#  'many',
#  'funny',
#  'Blah',
#  'anytime',
#  '4.00',
#  'potato',
#  'prime',
#  'constructed',
#  'disappointed',
#  'Bloody',
#  'nude',
#  'rapidly',
#  'Stopped',
#  'ones',
#  'read',
#  'raspberry',
#  'Insults',
#  'Burger',
#  'drinks',
#  'Restaurant',
#  'return',
#  'during',
#  'by',
#  'regularly',
#  'sangria',
#  'club',
#  'wrong',
#  'friendly',
#  'served',
#  'So',
#  'honestly',
#  'NOT',
#  'serivce',
#  'officially',
#  'The',
#  'bread',
#  'almonds',
#  'dont',
#  'tiny',
#  'used',
#  'yucky',
#  'twice',
#  'healthy',
#  'ripped',
#  'worst/annoying',
#  'as',
#  '-',
#  'watch',
#  'desired',
#  'forth',
#  'SHOULD',
#  'someone',
#  'usual',
#  'NEVER',
#  'accordingly',
#  'venue',
#  'those',
#  'massive',
#  'stale',
#  'soundtrack',
#  'strange',
#  'unique',
#  'my',
#  'shirt',
#  'highlight',
#  'VERY',
#  'short',
#  'Gave',
#  'describing',
#  'Dessert',
#  'been-stepped-in-and-tracked-everywhere',
#  'is',
#  'maybe',
#  'spotty',
#  'customer',
#  'stepped',
#  'point',
#  'cow',
#  'gets',
#  'Special',
#  'beans',
#  'muffin',
#  'sals',
#  'burgers',
#  'Joey',
#  'cash',
#  'actually',
#  'easily',
#  'douchey',
#  ',',
#  'vodka',
#  'Anyways',
#  'By',
#  'atrocious',
#  'TOLD',
#  'mind',
#  'drinking',
#  'absolutely',
#  'Overall',
#  'has',
#  'typical',
#  'disappointing',
#  'pleasure',
#  'lacked',
#  'getting',
#  'recommend',
#  'stuff',
#  'miss',
#  '%',
#  'soooooo',
#  'Please',
#  'Hell',
#  'worth',
#  'Def',
#  'Voodoo',
#  'Flower',
#  'quickly',
#  'tragedy',
#  'lightly',
#  'Why',
#  'positive',
#  'over-priced',
#  'crumby',
#  'tacos',
#  'smooth',
#  '-My',
#  'tolerance',
#  'give',
#  'girlfriend',
#  'vibe',
#  'offers',
#  'guests',
#  'owners',
#  'profiterole',
#  'atmosphere.1',
#  'disgusted',
#  'Phoenix',
#  'unbelievable',
#  'lighting',
#  'Carly',
#  'hereas',
#  'pile',
#  'English',
#  'non-fancy',
#  'Penne',
#  'classic',
#  'mortified',
#  'be',
#  'guest',
#  'somewhat',
#  'and',
#  'couples',
#  'Poor',
#  'spots',
#  'Seafood',
#  'prepared',
#  'Frenchman',
#  'Maybe',
#  'sashimi',
#  'Much',
#  'highlights',
#  'spice',
#  'min',
#  'bamboo',
#  'Baseball',
#  'today',
#  'figured',
#  'Ironman',
#  'Edinburgh',
#  'employee',
#  'rarely',
#  'strings',
#  'loved',
#  'court',
#  'so',
#  'on',
#  'dropped',
#  'seasonal',
#  'after',
#  'also',
#  'tomato',
#  'hard',
#  'cart',
#  'dedicated',
#  'smoothies',
#  'vain',
#  'whole',
#  'temp.I',
#  'become',
#  'set',
#  'Las',
#  'piece',
#  'lacking',
#  'BARGAIN',
#  'fry',
#  'bruschetta',
#  'space',
#  'one',
#  'surprise',
#  'style',
#  'back',
#  'cant',
#  'fail',
#  'Waiter',
#  'crab',
#  'block',
#  'From',
#  'beauty',
#  'attached',
#  'went',
#  'opportunity',
#  'Nargile',
#  'Cute',
#  'hilarious',
#  'pepper',
#  'chocolate',
#  'party',
#  'ignore',
#  'flop',
#  'have',
#  'dusted',
#  'teeth',
#  'prefer',
#  'occasional',
#  'DELICIOUS',
#  'humiliated',
#  'saving',
#  'relax',
#  'reminds',
#  'GREAT',
#  'dirty',
#  'attack',
#  'hi',
#  'beer',
#  'tribute',
#  'Long',
#  'shoe',
#  'grab',
#  'summarize',
#  'rare',
#  'doubt',
#  'dinners',
#  'unprofessional',
#  'saying',
#  'felt',
#  'fresh',
#  'taste',
#  'things',
#  'trips',
#  'falling',
#  'metro',
#  'avoid',
#  'part',
#  'its',
#  'satisfying',
#  'Tasted',
#  'ordered',
#  'This',
#  '7.85',
#  'places',
#  'Boy',
#  'reasons',
#  'second',
#  'HAPPENED',
#  'do',
#  'probably',
#  "'s",
#  'accountant',
#  'wound',
#  'excellent',
#  'others',
#  'potatoes',
#  'TIME',
#  'disgust',
#  'sporting',
#  'folks',
#  'none',
#  'average',
#  'downright',
#  'Could',
#  'gyro',
#  'show',
#  'Paradise',
#  'for',
#  'bartender',
#  'refused',
#  'events',
#  'pack',
#  'guy',
#  'flavorful',
#  'pork',
#  'pink',
#  'help',
#  'delish',
#  'toro',
#  'claimed',
#  'BETTER',
#  '45',
#  'visited',
#  'eaten',
#  'thin',
#  'yellow',
#  'choose',
#  'cheeseburger',
#  'believe',
#  'seating',
#  'rated',
#  'Buffet',
#  'just',
#  'disrespected',
#  'And',
#  'warnings',
#  'life',
#  'dispenser',
#  'fact',
#  'forgetting',
#  'bunch',
#  'GO',
#  'waited',
#  'delicate',
#  'pneumatic',
#  'You',
#  'Good',
#  'ambiance',
#  'trimmed',
#  'vegetables',
#  'Magazine',
#  'anything',
#  'article',
#  'Damn',
#  'Tonight',
#  'piano',
#  'lighter',
#  'Bussell',
#  'Mediterranean',
#  'brick',
#  'hour',
#  'platter',
#  'Lobster',
#  'Greek',
#  'walked',
#  '.way',
#  'location',
#  'meet',
#  'fuzzy',
#  'steakhouse',
#  'pecan',
#  'affordable',
#  'number',
#  'else',
#  'unhealthy',
#  'were',
#  'Kabuki',
#  'auju',
#  'chai',
#  'workers',
#  'huge',
#  'drunk',
#  'tender',
#  'BEST',
#  'Gordon',
#  'MANAGEMENT',
#  'extensive',
#  'boys',
#  'Have',
#  'avoided',
#  'happened',
#  'yet',
#  'CONCLUSION',
#  'middle',
#  'NO',
#  'ways',
#  'violinists',
#  'mary',
#  'assure',
#  'him',
#  'Shop',
#  'everyone',
#  'judging',
#  'deliver',
#  'pub',
#  'alone',
#  '..ohhh',
#  'bone',
#  'meats',
#  '15',
#  'Any',
#  'pricing',
#  'Sunday',
#  'did',
#  'fell',
#  'Eve',
#  'interesting',
#  'promise',
#  '10',
#  'pepper..and',
#  'croutons',
#  'drawing',
#  'mesquite',
#  'Weird',
#  'grocery',
#  'totally',
#  'tailored',
#  'opinion',
#  'ensued',
#  'boring',
#  'Firehouse',
#  'pulled',
#  'mess',
#  'neighborhood',
#  'rubber',
#  'Cape',
#  'ALL',
#  'These',
#  'businesses',
#  'winner',
#  'Friend',
#  'favor',
#  'SCREAMS',
#  'enjoyed',
#  'offered',
#  'callings',
#  'heard',
#  'gratitude',
#  'mouths',
#  'enjoyable',
#  'Del',
#  'event',
#  'are',
#  'Server',
#  'die',
#  'patty',
#  'been',
#  'promptly',
#  'Things',
#  'Terrible',
#  'that',
#  'recommending',
#  '7',
#  'vinaigrette',
#  'their',
#  'Bean',
#  'will',
#  'chefs',
#  'impressed',
#  'Are',
#  'Before',
#  'via',
#  'sick',
#  'WHAT',
#  'word',
#  'Sauce',
#  'charming',
#  'Café',
#  'hot',
#  'most',
#  'customize',
#  'fair',
#  'joint',
#  'Favorite',
#  'mention',
#  'found',
#  'guess',
#  'colder',
#  "'ve",
#  'ribeye',
#  'heat',
#  'front',
#  'REALLY',
#  'establishment',
#  'hooked',
#  'flair',
#  'very',
#  'Pho',
#  'chickens',
#  'really',
#  'chicken',
#  'imagined',
#  'Nicest',
#  'simply',
#  'Some',
#  'app',
#  'biggest',
#  'flirting',
#  'STALE',
#  'cannoli',
#  'Strip',
#  '...',
#  'inside',
#  'unwelcome',
#  'lost',
#  'cake',
#  'vomited',
#  'owned',
#  'bother',
#  'butter',
#  'done',
#  'station',
#  'play',
#  'ended',
#  'FS',
#  'patio',
#  'quick',
#  'hardly',
#  'understand',
#  'old',
#  'hankering',
#  'may',
#  'would',
#  'break',
#  'want',
#  'FLAVOR',
#  'crowds',
#  'shots',
#  'fast',
#  'decision',
#  'gyros',
#  'absolute',
#  'familiar',
#  'fluffy',
#  'warmer',
#  'Reasonably',
#  'similar',
#  'them',
#  'literally',
#  'containers',
#  'Luke',
#  'effort',
#  'Subway',
#  'stinks',
#  'Cartel',
#  'sergeant',
#  'finally',
#  'preparing',
#  'WAAAAAAyyyyyyyyyy',
#  'noodles',
#  'theft',
#  'Han',
#  'shops',
#  'appealing',
#  'cover',
#  'wide',
#  'fine',
#  "n't",
#  'My',
#  'wonderful',
#  '$',
#  'cramming',
#  'shall',
#  'decide',
#  'Service',
#  'Back',
#  'comfortable',
#  'big',
#  'selections',
#  'voted',
#  'rowdy',
#  'please',
#  'exceeding',
#  'Excalibur',
#  'generic',
#  'otherwise',
#  'eat',
#  'running',
#  'diverse',
#  'Toast',
#  'sugary',
#  'time',
#  'free',
#  'can',
#  'Dos',
#  'jewel',
#  'OMG',
#  'friend',
#  'deeply',
#  'ago',
#  's',
#  'cool',
#  '3/4ths',
#  'Roll',
#  'oil',
#  'apparently',
#  'nothing',
#  'Hands',
#  'milkshake',
#  'bill',
#  'Soi',
#  'cashier',
#  'HAD',
#  'care',
#  'forty',
#  'music',
#  'contain',
#  'Egg',
#  'Owner',
#  'To',
#  '5',
#  'efficient',
#  'door',
#  'larger',
#  'use',
#  'specials',
#  'iced',
#  'who',
#  'foot',
#  'OK',
#  'unexperienced',
#  'peach',
#  'anymore',
#  ...}

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    index_word[n] = word
    n += 1

# %%
word_index
# Out:
# {'Will': 0,
#  'Frozen': 1,
#  'milk': 2,
#  'bar': 3,
#  'summary': 4,
#  'rate': 5,
#  'caught': 6,
#  'wedges': 7,
#  'airline': 8,
#  'simple': 9,
#  'Gold': 10,
#  'around': 11,
#  'loves': 12,
#  'gave': 13,
#  'town': 14,
#  'given': 15,
#  'ice': 16,
#  'AVOID': 17,
#  'Seat': 18,
#  'besides': 19,
#  'uploaded': 20,
#  'longer': 21,
#  'stomach': 22,
#  'Hut': 23,
#  'sorely': 24,
#  'spring': 25,
#  'chef': 26,
#  'insulted': 27,
#  'ache': 28,
#  'continue': 29,
#  'server': 30,
#  'living': 31,
#  'devine': 32,
#  'dish': 33,
#  'trying': 34,
#  'FANTASTIC': 35,
#  'especially': 36,
#  'Coffee': 37,
#  'before': 38,
#  'BITCHES': 39,
#  'Sour': 40,
#  'chips': 41,
#  'expected': 42,
#  'creamy': 43,
#  'Ians': 44,
#  'concept': 45,
#  'passed': 46,
#  'since': 47,
#  'common': 48,
#  'spends': 49,
#  'Waited': 50,
#  'lover': 51,
#  'songs': 52,
#  'neat': 53,
#  'decorated': 54,
#  'Overpriced': 55,
#  "'re": 56,
#  'flavored': 57,
#  'wow': 58,
#  'damn': 59,
#  'On': 60,
#  'ambience': 61,
#  'almost': 62,
#  'talk': 63,
#  'double': 64,
#  'Sadly': 65,
#  'gone': 66,
#  'table': 67,
#  'papers': 68,
#  'sat': 69,
#  'blandest': 70,
#  'they': 71,
#  'fear': 72,
#  'delightful': 73,
#  'medium': 74,
#  'below': 75,
#  'pan': 76,
#  'blown': 77,
#  'wife': 78,
#  'mozzarella': 79,
#  'Bellagio': 80,
#  'bagels': 81,
#  'Cant': 82,
#  'Khao': 83,
#  'indoor': 84,
#  'Thoroughly': 85,
#  'Love': 86,
#  'Avoid': 87,
#  'dealing': 88,
#  'now': 89,
#  'works': 90,
#  'missing': 91,
#  'Not': 92,
#  'wayyy': 93,
#  'sub-par': 94,
#  'madhouse': 95,
#  'leaves': 96,
#  'like': 97,
#  'had': 98,
#  'succulent': 99,
#  'crepe': 100,
#  'corn': 101,
#  'One': 102,
#  'THAT': 103,
#  'friends': 104,
#  'never': 105,
#  'editing': 106,
#  'themselves': 107,
#  'martini': 108,
#  "'": 109,
#  'replenished': 110,
#  'three': 111,
#  'lil': 112,
#  'Vegas': 113,
#  'experiencing': 114,
#  'pears': 115,
#  'teamwork': 116,
#  'cheap': 117,
#  '..there': 118,
#  'bite': 119,
#  'gluten': 120,
#  'tasteless': 121,
#  'Steiners': 122,
#  'flavors': 123,
#  'Thai': 124,
#  'quite': 125,
#  'incredibly': 126,
#  'full': 127,
#  'couple': 128,
#  'Smashburger': 129,
#  'tapas': 130,
#  'sit-down': 131,
#  'ever': 132,
#  'car': 133,
#  'soggy': 134,
#  'refrained': 135,
#  'doing': 136,
#  'An': 137,
#  'angry': 138,
#  'slices': 139,
#  'chow': 140,
#  "'m": 141,
#  'owner': 142,
#  'regular': 143,
#  'Plater': 144,
#  'When': 145,
#  'boiled': 146,
#  'NASTY': 147,
#  'each': 148,
#  'transcendant': 149,
#  'Wonderful': 150,
#  'considering': 151,
#  'side': 152,
#  'kid': 153,
#  'first': 154,
#  'BACK': 155,
#  'Casino': 156,
#  'Vegetarian': 157,
#  'took': 158,
#  'turkey': 159,
#  'whatsoever': 160,
#  'blue': 161,
#  'Dog': 162,
#  'meal': 163,
#  'breaks': 164,
#  'duo': 165,
#  'waiting': 166,
#  'email': 167,
#  'presentation': 168,
#  'call': 169,
#  'moz': 170,
#  'Those': 171,
#  'hurry': 172,
#  'gross': 173,
#  'Big': 174,
#  'Update': 175,
#  'wasted': 176,
#  'spices': 177,
#  'bug': 178,
#  'occasions': 179,
#  'Nothing': 180,
#  'screwed': 181,
#  'famous': 182,
#  '100': 183,
#  'fantastic': 184,
#  'take': 185,
#  'High-quality': 186,
#  'duck': 187,
#  'me..Bunch': 188,
#  'in': 189,
#  'acknowledged': 190,
#  'bakery': 191,
#  'UNREAL': 192,
#  'pasta': 193,
#  'North': 194,
#  'expect': 195,
#  'wagyu': 196,
#  'live': 197,
#  'polite': 198,
#  'Mandalay': 199,
#  'find': 200,
#  'Heimer': 201,
#  'opened': 202,
#  'managed': 203,
#  'Left': 204,
#  'wine': 205,
#  'well': 206,
#  'Spend': 207,
#  'Disappointing': 208,
#  'trap': 209,
#  'ignored': 210,
#  'eggplant': 211,
#  'Honestly': 212,
#  'May': 213,
#  'warm': 214,
#  'several': 215,
#  'problem': 216,
#  '.THE': 217,
#  'sucker': 218,
#  'Plus': 219,
#  'fav': 220,
#  'although': 221,
#  'cost': 222,
#  ':': 223,
#  'Main': 224,
#  'meat': 225,
#  '2': 226,
#  'last': 227,
#  'hungry': 228,
#  'Shrimp-': 229,
#  'nasty': 230,
#  'five': 231,
#  'accomodate': 232,
#  'Taco': 233,
#  'Kids': 234,
#  'hostess': 235,
#  'customers': 236,
#  'placed': 237,
#  'glad': 238,
#  'filling': 239,
#  'multiple': 240,
#  'ethic': 241,
#  'pastry': 242,
#  'ESTABLISHMENT': 243,
#  'Anyway': 244,
#  'Sooooo': 245,
#  'patron': 246,
#  'boba': 247,
#  'putting': 248,
#  'caring': 249,
#  'smeared': 250,
#  'Ganoush': 251,
#  'Salad': 252,
#  'haunt': 253,
#  'TV': 254,
#  'night': 255,
#  'section': 256,
#  'closed': 257,
#  'menus': 258,
#  'poorly': 259,
#  'sitting': 260,
#  'starving': 261,
#  'hole': 262,
#  'binge': 263,
#  'expectations': 264,
#  'hopes': 265,
#  'HOUR': 266,
#  'cooking': 267,
#  'everything': 268,
#  'classics': 269,
#  'Horrible': 270,
#  'our': 271,
#  'gooodd': 272,
#  'Mary': 273,
#  'Despite': 274,
#  'stretch': 275,
#  'reheated': 276,
#  'relleno': 277,
#  'delight': 278,
#  'outshining': 279,
#  'provided': 280,
#  'basically': 281,
#  'waitress': 282,
#  'does': 283,
#  'reading': 284,
#  'guacamole': 285,
#  'dreamed': 286,
#  'remember': 287,
#  'circumstances': 288,
#  'happier': 289,
#  'BARE': 290,
#  'priced': 291,
#  'Pretty': 292,
#  'WASTE': 293,
#  'chip': 294,
#  'Maria': 295,
#  'Always': 296,
#  'honest': 297,
#  'elegantly': 298,
#  'greedy': 299,
#  'deal': 300,
#  'NONE': 301,
#  'pancakes': 302,
#  'blame': 303,
#  'coupons': 304,
#  'compliments': 305,
#  'tell': 306,
#  'Standard': 307,
#  'more': 308,
#  'Crema': 309,
#  'solid': 310,
#  'exceptional': 311,
#  'dog': 312,
#  'tasted': 313,
#  'enough': 314,
#  'business': 315,
#  'tables': 316,
#  'combination': 317,
#  'golden-crispy': 318,
#  'then': 319,
#  'They': 320,
#  'bodes': 321,
#  'traditional': 322,
#  'tough': 323,
#  'market': 324,
#  'fella': 325,
#  'upgrading': 326,
#  'Cotta': 327,
#  'Appetite': 328,
#  'Based': 329,
#  'poisoning': 330,
#  'Fridays': 331,
#  'changing': 332,
#  "'d": 333,
#  'fruit': 334,
#  'Everything': 335,
#  'loving': 336,
#  'approval': 337,
#  'crawfish': 338,
#  'hate': 339,
#  'cut': 340,
#  'reasonable': 341,
#  'MGM': 342,
#  'holiday': 343,
#  'husband': 344,
#  'Yelpers': 345,
#  'Hunan': 346,
#  'unsatisfying': 347,
#  'perfection': 348,
#  'spicy': 349,
#  '?': 350,
#  'price': 351,
#  'barely': 352,
#  'Took': 353,
#  'nutshell': 354,
#  'mostly': 355,
#  'A': 356,
#  'frozen': 357,
#  'Company': 358,
#  'unless': 359,
#  'Tucson': 360,
#  'flavourful': 361,
#  'including': 362,
#  'later': 363,
#  'beyond': 364,
#  'Must': 365,
#  'expert/connisseur': 366,
#  'legs': 367,
#  'nice': 368,
#  'swung': 369,
#  'food/service': 370,
#  'thinly': 371,
#  'anyone': 372,
#  'choux': 373,
#  'dressed': 374,
#  'grandmother': 375,
#  'seems': 376,
#  'salad': 377,
#  'Awful': 378,
#  'condiment': 379,
#  '.off': 380,
#  'ala': 381,
#  '40': 382,
#  'Eclectic': 383,
#  'Check': 384,
#  'reservation': 385,
#  'suck': 386,
#  "'ll": 387,
#  'outstanding': 388,
#  'airport': 389,
#  'taco': 390,
#  'many': 391,
#  'funny': 392,
#  'Blah': 393,
#  'anytime': 394,
#  '4.00': 395,
#  'potato': 396,
#  'prime': 397,
#  'constructed': 398,
#  'disappointed': 399,
#  'Bloody': 400,
#  'nude': 401,
#  'rapidly': 402,
#  'Stopped': 403,
#  'ones': 404,
#  'read': 405,
#  'raspberry': 406,
#  'Insults': 407,
#  'Burger': 408,
#  'drinks': 409,
#  'Restaurant': 410,
#  'return': 411,
#  'during': 412,
#  'by': 413,
#  'regularly': 414,
#  'sangria': 415,
#  'club': 416,
#  'wrong': 417,
#  'friendly': 418,
#  'served': 419,
#  'So': 420,
#  'honestly': 421,
#  'NOT': 422,
#  'serivce': 423,
#  'officially': 424,
#  'The': 425,
#  'bread': 426,
#  'almonds': 427,
#  'dont': 428,
#  'tiny': 429,
#  'used': 430,
#  'yucky': 431,
#  'twice': 432,
#  'healthy': 433,
#  'ripped': 434,
#  'worst/annoying': 435,
#  'as': 436,
#  '-': 437,
#  'watch': 438,
#  'desired': 439,
#  'forth': 440,
#  'SHOULD': 441,
#  'someone': 442,
#  'usual': 443,
#  'NEVER': 444,
#  'accordingly': 445,
#  'venue': 446,
#  'those': 447,
#  'massive': 448,
#  'stale': 449,
#  'soundtrack': 450,
#  'strange': 451,
#  'unique': 452,
#  'my': 453,
#  'shirt': 454,
#  'highlight': 455,
#  'VERY': 456,
#  'short': 457,
#  'Gave': 458,
#  'describing': 459,
#  'Dessert': 460,
#  'been-stepped-in-and-tracked-everywhere': 461,
#  'is': 462,
#  'maybe': 463,
#  'spotty': 464,
#  'customer': 465,
#  'stepped': 466,
#  'point': 467,
#  'cow': 468,
#  'gets': 469,
#  'Special': 470,
#  'beans': 471,
#  'muffin': 472,
#  'sals': 473,
#  'burgers': 474,
#  'Joey': 475,
#  'cash': 476,
#  'actually': 477,
#  'easily': 478,
#  'douchey': 479,
#  ',': 480,
#  'vodka': 481,
#  'Anyways': 482,
#  'By': 483,
#  'atrocious': 484,
#  'TOLD': 485,
#  'mind': 486,
#  'drinking': 487,
#  'absolutely': 488,
#  'Overall': 489,
#  'has': 490,
#  'typical': 491,
#  'disappointing': 492,
#  'pleasure': 493,
#  'lacked': 494,
#  'getting': 495,
#  'recommend': 496,
#  'stuff': 497,
#  'miss': 498,
#  '%': 499,
#  'soooooo': 500,
#  'Please': 501,
#  'Hell': 502,
#  'worth': 503,
#  'Def': 504,
#  'Voodoo': 505,
#  'Flower': 506,
#  'quickly': 507,
#  'tragedy': 508,
#  'lightly': 509,
#  'Why': 510,
#  'positive': 511,
#  'over-priced': 512,
#  'crumby': 513,
#  'tacos': 514,
#  'smooth': 515,
#  '-My': 516,
#  'tolerance': 517,
#  'give': 518,
#  'girlfriend': 519,
#  'vibe': 520,
#  'offers': 521,
#  'guests': 522,
#  'owners': 523,
#  'profiterole': 524,
#  'atmosphere.1': 525,
#  'disgusted': 526,
#  'Phoenix': 527,
#  'unbelievable': 528,
#  'lighting': 529,
#  'Carly': 530,
#  'hereas': 531,
#  'pile': 532,
#  'English': 533,
#  'non-fancy': 534,
#  'Penne': 535,
#  'classic': 536,
#  'mortified': 537,
#  'be': 538,
#  'guest': 539,
#  'somewhat': 540,
#  'and': 541,
#  'couples': 542,
#  'Poor': 543,
#  'spots': 544,
#  'Seafood': 545,
#  'prepared': 546,
#  'Frenchman': 547,
#  'Maybe': 548,
#  'sashimi': 549,
#  'Much': 550,
#  'highlights': 551,
#  'spice': 552,
#  'min': 553,
#  'bamboo': 554,
#  'Baseball': 555,
#  'today': 556,
#  'figured': 557,
#  'Ironman': 558,
#  'Edinburgh': 559,
#  'employee': 560,
#  'rarely': 561,
#  'strings': 562,
#  'loved': 563,
#  'court': 564,
#  'so': 565,
#  'on': 566,
#  'dropped': 567,
#  'seasonal': 568,
#  'after': 569,
#  'also': 570,
#  'tomato': 571,
#  'hard': 572,
#  'cart': 573,
#  'dedicated': 574,
#  'smoothies': 575,
#  'vain': 576,
#  'whole': 577,
#  'temp.I': 578,
#  'become': 579,
#  'set': 580,
#  'Las': 581,
#  'piece': 582,
#  'lacking': 583,
#  'BARGAIN': 584,
#  'fry': 585,
#  'bruschetta': 586,
#  'space': 587,
#  'one': 588,
#  'surprise': 589,
#  'style': 590,
#  'back': 591,
#  'cant': 592,
#  'fail': 593,
#  'Waiter': 594,
#  'crab': 595,
#  'block': 596,
#  'From': 597,
#  'beauty': 598,
#  'attached': 599,
#  'went': 600,
#  'opportunity': 601,
#  'Nargile': 602,
#  'Cute': 603,
#  'hilarious': 604,
#  'pepper': 605,
#  'chocolate': 606,
#  'party': 607,
#  'ignore': 608,
#  'flop': 609,
#  'have': 610,
#  'dusted': 611,
#  'teeth': 612,
#  'prefer': 613,
#  'occasional': 614,
#  'DELICIOUS': 615,
#  'humiliated': 616,
#  'saving': 617,
#  'relax': 618,
#  'reminds': 619,
#  'GREAT': 620,
#  'dirty': 621,
#  'attack': 622,
#  'hi': 623,
#  'beer': 624,
#  'tribute': 625,
#  'Long': 626,
#  'shoe': 627,
#  'grab': 628,
#  'summarize': 629,
#  'rare': 630,
#  'doubt': 631,
#  'dinners': 632,
#  'unprofessional': 633,
#  'saying': 634,
#  'felt': 635,
#  'fresh': 636,
#  'taste': 637,
#  'things': 638,
#  'trips': 639,
#  'falling': 640,
#  'metro': 641,
#  'avoid': 642,
#  'part': 643,
#  'its': 644,
#  'satisfying': 645,
#  'Tasted': 646,
#  'ordered': 647,
#  'This': 648,
#  '7.85': 649,
#  'places': 650,
#  'Boy': 651,
#  'reasons': 652,
#  'second': 653,
#  'HAPPENED': 654,
#  'do': 655,
#  'probably': 656,
#  "'s": 657,
#  'accountant': 658,
#  'wound': 659,
#  'excellent': 660,
#  'others': 661,
#  'potatoes': 662,
#  'TIME': 663,
#  'disgust': 664,
#  'sporting': 665,
#  'folks': 666,
#  'none': 667,
#  'average': 668,
#  'downright': 669,
#  'Could': 670,
#  'gyro': 671,
#  'show': 672,
#  'Paradise': 673,
#  'for': 674,
#  'bartender': 675,
#  'refused': 676,
#  'events': 677,
#  'pack': 678,
#  'guy': 679,
#  'flavorful': 680,
#  'pork': 681,
#  'pink': 682,
#  'help': 683,
#  'delish': 684,
#  'toro': 685,
#  'claimed': 686,
#  'BETTER': 687,
#  '45': 688,
#  'visited': 689,
#  'eaten': 690,
#  'thin': 691,
#  'yellow': 692,
#  'choose': 693,
#  'cheeseburger': 694,
#  'believe': 695,
#  'seating': 696,
#  'rated': 697,
#  'Buffet': 698,
#  'just': 699,
#  'disrespected': 700,
#  'And': 701,
#  'warnings': 702,
#  'life': 703,
#  'dispenser': 704,
#  'fact': 705,
#  'forgetting': 706,
#  'bunch': 707,
#  'GO': 708,
#  'waited': 709,
#  'delicate': 710,
#  'pneumatic': 711,
#  'You': 712,
#  'Good': 713,
#  'ambiance': 714,
#  'trimmed': 715,
#  'vegetables': 716,
#  'Magazine': 717,
#  'anything': 718,
#  'article': 719,
#  'Damn': 720,
#  'Tonight': 721,
#  'piano': 722,
#  'lighter': 723,
#  'Bussell': 724,
#  'Mediterranean': 725,
#  'brick': 726,
#  'hour': 727,
#  'platter': 728,
#  'Lobster': 729,
#  'Greek': 730,
#  'walked': 731,
#  '.way': 732,
#  'location': 733,
#  'meet': 734,
#  'fuzzy': 735,
#  'steakhouse': 736,
#  'pecan': 737,
#  'affordable': 738,
#  'number': 739,
#  'else': 740,
#  'unhealthy': 741,
#  'were': 742,
#  'Kabuki': 743,
#  'auju': 744,
#  'chai': 745,
#  'workers': 746,
#  'huge': 747,
#  'drunk': 748,
#  'tender': 749,
#  'BEST': 750,
#  'Gordon': 751,
#  'MANAGEMENT': 752,
#  'extensive': 753,
#  'boys': 754,
#  'Have': 755,
#  'avoided': 756,
#  'happened': 757,
#  'yet': 758,
#  'CONCLUSION': 759,
#  'middle': 760,
#  'NO': 761,
#  'ways': 762,
#  'violinists': 763,
#  'mary': 764,
#  'assure': 765,
#  'him': 766,
#  'Shop': 767,
#  'everyone': 768,
#  'judging': 769,
#  'deliver': 770,
#  'pub': 771,
#  'alone': 772,
#  '..ohhh': 773,
#  'bone': 774,
#  'meats': 775,
#  '15': 776,
#  'Any': 777,
#  'pricing': 778,
#  'Sunday': 779,
#  'did': 780,
#  'fell': 781,
#  'Eve': 782,
#  'interesting': 783,
#  'promise': 784,
#  '10': 785,
#  'pepper..and': 786,
#  'croutons': 787,
#  'drawing': 788,
#  'mesquite': 789,
#  'Weird': 790,
#  'grocery': 791,
#  'totally': 792,
#  'tailored': 793,
#  'opinion': 794,
#  'ensued': 795,
#  'boring': 796,
#  'Firehouse': 797,
#  'pulled': 798,
#  'mess': 799,
#  'neighborhood': 800,
#  'rubber': 801,
#  'Cape': 802,
#  'ALL': 803,
#  'These': 804,
#  'businesses': 805,
#  'winner': 806,
#  'Friend': 807,
#  'favor': 808,
#  'SCREAMS': 809,
#  'enjoyed': 810,
#  'offered': 811,
#  'callings': 812,
#  'heard': 813,
#  'gratitude': 814,
#  'mouths': 815,
#  'enjoyable': 816,
#  'Del': 817,
#  'event': 818,
#  'are': 819,
#  'Server': 820,
#  'die': 821,
#  'patty': 822,
#  'been': 823,
#  'promptly': 824,
#  'Things': 825,
#  'Terrible': 826,
#  'that': 827,
#  'recommending': 828,
#  '7': 829,
#  'vinaigrette': 830,
#  'their': 831,
#  'Bean': 832,
#  'will': 833,
#  'chefs': 834,
#  'impressed': 835,
#  'Are': 836,
#  'Before': 837,
#  'via': 838,
#  'sick': 839,
#  'WHAT': 840,
#  'word': 841,
#  'Sauce': 842,
#  'charming': 843,
#  'Café': 844,
#  'hot': 845,
#  'most': 846,
#  'customize': 847,
#  'fair': 848,
#  'joint': 849,
#  'Favorite': 850,
#  'mention': 851,
#  'found': 852,
#  'guess': 853,
#  'colder': 854,
#  "'ve": 855,
#  'ribeye': 856,
#  'heat': 857,
#  'front': 858,
#  'REALLY': 859,
#  'establishment': 860,
#  'hooked': 861,
#  'flair': 862,
#  'very': 863,
#  'Pho': 864,
#  'chickens': 865,
#  'really': 866,
#  'chicken': 867,
#  'imagined': 868,
#  'Nicest': 869,
#  'simply': 870,
#  'Some': 871,
#  'app': 872,
#  'biggest': 873,
#  'flirting': 874,
#  'STALE': 875,
#  'cannoli': 876,
#  'Strip': 877,
#  '...': 878,
#  'inside': 879,
#  'unwelcome': 880,
#  'lost': 881,
#  'cake': 882,
#  'vomited': 883,
#  'owned': 884,
#  'bother': 885,
#  'butter': 886,
#  'done': 887,
#  'station': 888,
#  'play': 889,
#  'ended': 890,
#  'FS': 891,
#  'patio': 892,
#  'quick': 893,
#  'hardly': 894,
#  'understand': 895,
#  'old': 896,
#  'hankering': 897,
#  'may': 898,
#  'would': 899,
#  'break': 900,
#  'want': 901,
#  'FLAVOR': 902,
#  'crowds': 903,
#  'shots': 904,
#  'fast': 905,
#  'decision': 906,
#  'gyros': 907,
#  'absolute': 908,
#  'familiar': 909,
#  'fluffy': 910,
#  'warmer': 911,
#  'Reasonably': 912,
#  'similar': 913,
#  'them': 914,
#  'literally': 915,
#  'containers': 916,
#  'Luke': 917,
#  'effort': 918,
#  'Subway': 919,
#  'stinks': 920,
#  'Cartel': 921,
#  'sergeant': 922,
#  'finally': 923,
#  'preparing': 924,
#  'WAAAAAAyyyyyyyyyy': 925,
#  'noodles': 926,
#  'theft': 927,
#  'Han': 928,
#  'shops': 929,
#  'appealing': 930,
#  'cover': 931,
#  'wide': 932,
#  'fine': 933,
#  "n't": 934,
#  'My': 935,
#  'wonderful': 936,
#  '$': 937,
#  'cramming': 938,
#  'shall': 939,
#  'decide': 940,
#  'Service': 941,
#  'Back': 942,
#  'comfortable': 943,
#  'big': 944,
#  'selections': 945,
#  'voted': 946,
#  'rowdy': 947,
#  'please': 948,
#  'exceeding': 949,
#  'Excalibur': 950,
#  'generic': 951,
#  'otherwise': 952,
#  'eat': 953,
#  'running': 954,
#  'diverse': 955,
#  'Toast': 956,
#  'sugary': 957,
#  'time': 958,
#  'free': 959,
#  'can': 960,
#  'Dos': 961,
#  'jewel': 962,
#  'OMG': 963,
#  'friend': 964,
#  'deeply': 965,
#  'ago': 966,
#  's': 967,
#  'cool': 968,
#  '3/4ths': 969,
#  'Roll': 970,
#  'oil': 971,
#  'apparently': 972,
#  'nothing': 973,
#  'Hands': 974,
#  'milkshake': 975,
#  'bill': 976,
#  'Soi': 977,
#  'cashier': 978,
#  'HAD': 979,
#  'care': 980,
#  'forty': 981,
#  'music': 982,
#  'contain': 983,
#  'Egg': 984,
#  'Owner': 985,
#  'To': 986,
#  '5': 987,
#  'efficient': 988,
#  'door': 989,
#  'larger': 990,
#  'use': 991,
#  'specials': 992,
#  'iced': 993,
#  'who': 994,
#  'foot': 995,
#  'OK': 996,
#  'unexperienced': 997,
#  'peach': 998,
#  'anymore': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'Will',
#  1: 'Frozen',
#  2: 'milk',
#  3: 'bar',
#  4: 'summary',
#  5: 'rate',
#  6: 'caught',
#  7: 'wedges',
#  8: 'airline',
#  9: 'simple',
#  10: 'Gold',
#  11: 'around',
#  12: 'loves',
#  13: 'gave',
#  14: 'town',
#  15: 'given',
#  16: 'ice',
#  17: 'AVOID',
#  18: 'Seat',
#  19: 'besides',
#  20: 'uploaded',
#  21: 'longer',
#  22: 'stomach',
#  23: 'Hut',
#  24: 'sorely',
#  25: 'spring',
#  26: 'chef',
#  27: 'insulted',
#  28: 'ache',
#  29: 'continue',
#  30: 'server',
#  31: 'living',
#  32: 'devine',
#  33: 'dish',
#  34: 'trying',
#  35: 'FANTASTIC',
#  36: 'especially',
#  37: 'Coffee',
#  38: 'before',
#  39: 'BITCHES',
#  40: 'Sour',
#  41: 'chips',
#  42: 'expected',
#  43: 'creamy',
#  44: 'Ians',
#  45: 'concept',
#  46: 'passed',
#  47: 'since',
#  48: 'common',
#  49: 'spends',
#  50: 'Waited',
#  51: 'lover',
#  52: 'songs',
#  53: 'neat',
#  54: 'decorated',
#  55: 'Overpriced',
#  56: "'re",
#  57: 'flavored',
#  58: 'wow',
#  59: 'damn',
#  60: 'On',
#  61: 'ambience',
#  62: 'almost',
#  63: 'talk',
#  64: 'double',
#  65: 'Sadly',
#  66: 'gone',
#  67: 'table',
#  68: 'papers',
#  69: 'sat',
#  70: 'blandest',
#  71: 'they',
#  72: 'fear',
#  73: 'delightful',
#  74: 'medium',
#  75: 'below',
#  76: 'pan',
#  77: 'blown',
#  78: 'wife',
#  79: 'mozzarella',
#  80: 'Bellagio',
#  81: 'bagels',
#  82: 'Cant',
#  83: 'Khao',
#  84: 'indoor',
#  85: 'Thoroughly',
#  86: 'Love',
#  87: 'Avoid',
#  88: 'dealing',
#  89: 'now',
#  90: 'works',
#  91: 'missing',
#  92: 'Not',
#  93: 'wayyy',
#  94: 'sub-par',
#  95: 'madhouse',
#  96: 'leaves',
#  97: 'like',
#  98: 'had',
#  99: 'succulent',
#  100: 'crepe',
#  101: 'corn',
#  102: 'One',
#  103: 'THAT',
#  104: 'friends',
#  105: 'never',
#  106: 'editing',
#  107: 'themselves',
#  108: 'martini',
#  109: "'",
#  110: 'replenished',
#  111: 'three',
#  112: 'lil',
#  113: 'Vegas',
#  114: 'experiencing',
#  115: 'pears',
#  116: 'teamwork',
#  117: 'cheap',
#  118: '..there',
#  119: 'bite',
#  120: 'gluten',
#  121: 'tasteless',
#  122: 'Steiners',
#  123: 'flavors',
#  124: 'Thai',
#  125: 'quite',
#  126: 'incredibly',
#  127: 'full',
#  128: 'couple',
#  129: 'Smashburger',
#  130: 'tapas',
#  131: 'sit-down',
#  132: 'ever',
#  133: 'car',
#  134: 'soggy',
#  135: 'refrained',
#  136: 'doing',
#  137: 'An',
#  138: 'angry',
#  139: 'slices',
#  140: 'chow',
#  141: "'m",
#  142: 'owner',
#  143: 'regular',
#  144: 'Plater',
#  145: 'When',
#  146: 'boiled',
#  147: 'NASTY',
#  148: 'each',
#  149: 'transcendant',
#  150: 'Wonderful',
#  151: 'considering',
#  152: 'side',
#  153: 'kid',
#  154: 'first',
#  155: 'BACK',
#  156: 'Casino',
#  157: 'Vegetarian',
#  158: 'took',
#  159: 'turkey',
#  160: 'whatsoever',
#  161: 'blue',
#  162: 'Dog',
#  163: 'meal',
#  164: 'breaks',
#  165: 'duo',
#  166: 'waiting',
#  167: 'email',
#  168: 'presentation',
#  169: 'call',
#  170: 'moz',
#  171: 'Those',
#  172: 'hurry',
#  173: 'gross',
#  174: 'Big',
#  175: 'Update',
#  176: 'wasted',
#  177: 'spices',
#  178: 'bug',
#  179: 'occasions',
#  180: 'Nothing',
#  181: 'screwed',
#  182: 'famous',
#  183: '100',
#  184: 'fantastic',
#  185: 'take',
#  186: 'High-quality',
#  187: 'duck',
#  188: 'me..Bunch',
#  189: 'in',
#  190: 'acknowledged',
#  191: 'bakery',
#  192: 'UNREAL',
#  193: 'pasta',
#  194: 'North',
#  195: 'expect',
#  196: 'wagyu',
#  197: 'live',
#  198: 'polite',
#  199: 'Mandalay',
#  200: 'find',
#  201: 'Heimer',
#  202: 'opened',
#  203: 'managed',
#  204: 'Left',
#  205: 'wine',
#  206: 'well',
#  207: 'Spend',
#  208: 'Disappointing',
#  209: 'trap',
#  210: 'ignored',
#  211: 'eggplant',
#  212: 'Honestly',
#  213: 'May',
#  214: 'warm',
#  215: 'several',
#  216: 'problem',
#  217: '.THE',
#  218: 'sucker',
#  219: 'Plus',
#  220: 'fav',
#  221: 'although',
#  222: 'cost',
#  223: ':',
#  224: 'Main',
#  225: 'meat',
#  226: '2',
#  227: 'last',
#  228: 'hungry',
#  229: 'Shrimp-',
#  230: 'nasty',
#  231: 'five',
#  232: 'accomodate',
#  233: 'Taco',
#  234: 'Kids',
#  235: 'hostess',
#  236: 'customers',
#  237: 'placed',
#  238: 'glad',
#  239: 'filling',
#  240: 'multiple',
#  241: 'ethic',
#  242: 'pastry',
#  243: 'ESTABLISHMENT',
#  244: 'Anyway',
#  245: 'Sooooo',
#  246: 'patron',
#  247: 'boba',
#  248: 'putting',
#  249: 'caring',
#  250: 'smeared',
#  251: 'Ganoush',
#  252: 'Salad',
#  253: 'haunt',
#  254: 'TV',
#  255: 'night',
#  256: 'section',
#  257: 'closed',
#  258: 'menus',
#  259: 'poorly',
#  260: 'sitting',
#  261: 'starving',
#  262: 'hole',
#  263: 'binge',
#  264: 'expectations',
#  265: 'hopes',
#  266: 'HOUR',
#  267: 'cooking',
#  268: 'everything',
#  269: 'classics',
#  270: 'Horrible',
#  271: 'our',
#  272: 'gooodd',
#  273: 'Mary',
#  274: 'Despite',
#  275: 'stretch',
#  276: 'reheated',
#  277: 'relleno',
#  278: 'delight',
#  279: 'outshining',
#  280: 'provided',
#  281: 'basically',
#  282: 'waitress',
#  283: 'does',
#  284: 'reading',
#  285: 'guacamole',
#  286: 'dreamed',
#  287: 'remember',
#  288: 'circumstances',
#  289: 'happier',
#  290: 'BARE',
#  291: 'priced',
#  292: 'Pretty',
#  293: 'WASTE',
#  294: 'chip',
#  295: 'Maria',
#  296: 'Always',
#  297: 'honest',
#  298: 'elegantly',
#  299: 'greedy',
#  300: 'deal',
#  301: 'NONE',
#  302: 'pancakes',
#  303: 'blame',
#  304: 'coupons',
#  305: 'compliments',
#  306: 'tell',
#  307: 'Standard',
#  308: 'more',
#  309: 'Crema',
#  310: 'solid',
#  311: 'exceptional',
#  312: 'dog',
#  313: 'tasted',
#  314: 'enough',
#  315: 'business',
#  316: 'tables',
#  317: 'combination',
#  318: 'golden-crispy',
#  319: 'then',
#  320: 'They',
#  321: 'bodes',
#  322: 'traditional',
#  323: 'tough',
#  324: 'market',
#  325: 'fella',
#  326: 'upgrading',
#  327: 'Cotta',
#  328: 'Appetite',
#  329: 'Based',
#  330: 'poisoning',
#  331: 'Fridays',
#  332: 'changing',
#  333: "'d",
#  334: 'fruit',
#  335: 'Everything',
#  336: 'loving',
#  337: 'approval',
#  338: 'crawfish',
#  339: 'hate',
#  340: 'cut',
#  341: 'reasonable',
#  342: 'MGM',
#  343: 'holiday',
#  344: 'husband',
#  345: 'Yelpers',
#  346: 'Hunan',
#  347: 'unsatisfying',
#  348: 'perfection',
#  349: 'spicy',
#  350: '?',
#  351: 'price',
#  352: 'barely',
#  353: 'Took',
#  354: 'nutshell',
#  355: 'mostly',
#  356: 'A',
#  357: 'frozen',
#  358: 'Company',
#  359: 'unless',
#  360: 'Tucson',
#  361: 'flavourful',
#  362: 'including',
#  363: 'later',
#  364: 'beyond',
#  365: 'Must',
#  366: 'expert/connisseur',
#  367: 'legs',
#  368: 'nice',
#  369: 'swung',
#  370: 'food/service',
#  371: 'thinly',
#  372: 'anyone',
#  373: 'choux',
#  374: 'dressed',
#  375: 'grandmother',
#  376: 'seems',
#  377: 'salad',
#  378: 'Awful',
#  379: 'condiment',
#  380: '.off',
#  381: 'ala',
#  382: '40',
#  383: 'Eclectic',
#  384: 'Check',
#  385: 'reservation',
#  386: 'suck',
#  387: "'ll",
#  388: 'outstanding',
#  389: 'airport',
#  390: 'taco',
#  391: 'many',
#  392: 'funny',
#  393: 'Blah',
#  394: 'anytime',
#  395: '4.00',
#  396: 'potato',
#  397: 'prime',
#  398: 'constructed',
#  399: 'disappointed',
#  400: 'Bloody',
#  401: 'nude',
#  402: 'rapidly',
#  403: 'Stopped',
#  404: 'ones',
#  405: 'read',
#  406: 'raspberry',
#  407: 'Insults',
#  408: 'Burger',
#  409: 'drinks',
#  410: 'Restaurant',
#  411: 'return',
#  412: 'during',
#  413: 'by',
#  414: 'regularly',
#  415: 'sangria',
#  416: 'club',
#  417: 'wrong',
#  418: 'friendly',
#  419: 'served',
#  420: 'So',
#  421: 'honestly',
#  422: 'NOT',
#  423: 'serivce',
#  424: 'officially',
#  425: 'The',
#  426: 'bread',
#  427: 'almonds',
#  428: 'dont',
#  429: 'tiny',
#  430: 'used',
#  431: 'yucky',
#  432: 'twice',
#  433: 'healthy',
#  434: 'ripped',
#  435: 'worst/annoying',
#  436: 'as',
#  437: '-',
#  438: 'watch',
#  439: 'desired',
#  440: 'forth',
#  441: 'SHOULD',
#  442: 'someone',
#  443: 'usual',
#  444: 'NEVER',
#  445: 'accordingly',
#  446: 'venue',
#  447: 'those',
#  448: 'massive',
#  449: 'stale',
#  450: 'soundtrack',
#  451: 'strange',
#  452: 'unique',
#  453: 'my',
#  454: 'shirt',
#  455: 'highlight',
#  456: 'VERY',
#  457: 'short',
#  458: 'Gave',
#  459: 'describing',
#  460: 'Dessert',
#  461: 'been-stepped-in-and-tracked-everywhere',
#  462: 'is',
#  463: 'maybe',
#  464: 'spotty',
#  465: 'customer',
#  466: 'stepped',
#  467: 'point',
#  468: 'cow',
#  469: 'gets',
#  470: 'Special',
#  471: 'beans',
#  472: 'muffin',
#  473: 'sals',
#  474: 'burgers',
#  475: 'Joey',
#  476: 'cash',
#  477: 'actually',
#  478: 'easily',
#  479: 'douchey',
#  480: ',',
#  481: 'vodka',
#  482: 'Anyways',
#  483: 'By',
#  484: 'atrocious',
#  485: 'TOLD',
#  486: 'mind',
#  487: 'drinking',
#  488: 'absolutely',
#  489: 'Overall',
#  490: 'has',
#  491: 'typical',
#  492: 'disappointing',
#  493: 'pleasure',
#  494: 'lacked',
#  495: 'getting',
#  496: 'recommend',
#  497: 'stuff',
#  498: 'miss',
#  499: '%',
#  500: 'soooooo',
#  501: 'Please',
#  502: 'Hell',
#  503: 'worth',
#  504: 'Def',
#  505: 'Voodoo',
#  506: 'Flower',
#  507: 'quickly',
#  508: 'tragedy',
#  509: 'lightly',
#  510: 'Why',
#  511: 'positive',
#  512: 'over-priced',
#  513: 'crumby',
#  514: 'tacos',
#  515: 'smooth',
#  516: '-My',
#  517: 'tolerance',
#  518: 'give',
#  519: 'girlfriend',
#  520: 'vibe',
#  521: 'offers',
#  522: 'guests',
#  523: 'owners',
#  524: 'profiterole',
#  525: 'atmosphere.1',
#  526: 'disgusted',
#  527: 'Phoenix',
#  528: 'unbelievable',
#  529: 'lighting',
#  530: 'Carly',
#  531: 'hereas',
#  532: 'pile',
#  533: 'English',
#  534: 'non-fancy',
#  535: 'Penne',
#  536: 'classic',
#  537: 'mortified',
#  538: 'be',
#  539: 'guest',
#  540: 'somewhat',
#  541: 'and',
#  542: 'couples',
#  543: 'Poor',
#  544: 'spots',
#  545: 'Seafood',
#  546: 'prepared',
#  547: 'Frenchman',
#  548: 'Maybe',
#  549: 'sashimi',
#  550: 'Much',
#  551: 'highlights',
#  552: 'spice',
#  553: 'min',
#  554: 'bamboo',
#  555: 'Baseball',
#  556: 'today',
#  557: 'figured',
#  558: 'Ironman',
#  559: 'Edinburgh',
#  560: 'employee',
#  561: 'rarely',
#  562: 'strings',
#  563: 'loved',
#  564: 'court',
#  565: 'so',
#  566: 'on',
#  567: 'dropped',
#  568: 'seasonal',
#  569: 'after',
#  570: 'also',
#  571: 'tomato',
#  572: 'hard',
#  573: 'cart',
#  574: 'dedicated',
#  575: 'smoothies',
#  576: 'vain',
#  577: 'whole',
#  578: 'temp.I',
#  579: 'become',
#  580: 'set',
#  581: 'Las',
#  582: 'piece',
#  583: 'lacking',
#  584: 'BARGAIN',
#  585: 'fry',
#  586: 'bruschetta',
#  587: 'space',
#  588: 'one',
#  589: 'surprise',
#  590: 'style',
#  591: 'back',
#  592: 'cant',
#  593: 'fail',
#  594: 'Waiter',
#  595: 'crab',
#  596: 'block',
#  597: 'From',
#  598: 'beauty',
#  599: 'attached',
#  600: 'went',
#  601: 'opportunity',
#  602: 'Nargile',
#  603: 'Cute',
#  604: 'hilarious',
#  605: 'pepper',
#  606: 'chocolate',
#  607: 'party',
#  608: 'ignore',
#  609: 'flop',
#  610: 'have',
#  611: 'dusted',
#  612: 'teeth',
#  613: 'prefer',
#  614: 'occasional',
#  615: 'DELICIOUS',
#  616: 'humiliated',
#  617: 'saving',
#  618: 'relax',
#  619: 'reminds',
#  620: 'GREAT',
#  621: 'dirty',
#  622: 'attack',
#  623: 'hi',
#  624: 'beer',
#  625: 'tribute',
#  626: 'Long',
#  627: 'shoe',
#  628: 'grab',
#  629: 'summarize',
#  630: 'rare',
#  631: 'doubt',
#  632: 'dinners',
#  633: 'unprofessional',
#  634: 'saying',
#  635: 'felt',
#  636: 'fresh',
#  637: 'taste',
#  638: 'things',
#  639: 'trips',
#  640: 'falling',
#  641: 'metro',
#  642: 'avoid',
#  643: 'part',
#  644: 'its',
#  645: 'satisfying',
#  646: 'Tasted',
#  647: 'ordered',
#  648: 'This',
#  649: '7.85',
#  650: 'places',
#  651: 'Boy',
#  652: 'reasons',
#  653: 'second',
#  654: 'HAPPENED',
#  655: 'do',
#  656: 'probably',
#  657: "'s",
#  658: 'accountant',
#  659: 'wound',
#  660: 'excellent',
#  661: 'others',
#  662: 'potatoes',
#  663: 'TIME',
#  664: 'disgust',
#  665: 'sporting',
#  666: 'folks',
#  667: 'none',
#  668: 'average',
#  669: 'downright',
#  670: 'Could',
#  671: 'gyro',
#  672: 'show',
#  673: 'Paradise',
#  674: 'for',
#  675: 'bartender',
#  676: 'refused',
#  677: 'events',
#  678: 'pack',
#  679: 'guy',
#  680: 'flavorful',
#  681: 'pork',
#  682: 'pink',
#  683: 'help',
#  684: 'delish',
#  685: 'toro',
#  686: 'claimed',
#  687: 'BETTER',
#  688: '45',
#  689: 'visited',
#  690: 'eaten',
#  691: 'thin',
#  692: 'yellow',
#  693: 'choose',
#  694: 'cheeseburger',
#  695: 'believe',
#  696: 'seating',
#  697: 'rated',
#  698: 'Buffet',
#  699: 'just',
#  700: 'disrespected',
#  701: 'And',
#  702: 'warnings',
#  703: 'life',
#  704: 'dispenser',
#  705: 'fact',
#  706: 'forgetting',
#  707: 'bunch',
#  708: 'GO',
#  709: 'waited',
#  710: 'delicate',
#  711: 'pneumatic',
#  712: 'You',
#  713: 'Good',
#  714: 'ambiance',
#  715: 'trimmed',
#  716: 'vegetables',
#  717: 'Magazine',
#  718: 'anything',
#  719: 'article',
#  720: 'Damn',
#  721: 'Tonight',
#  722: 'piano',
#  723: 'lighter',
#  724: 'Bussell',
#  725: 'Mediterranean',
#  726: 'brick',
#  727: 'hour',
#  728: 'platter',
#  729: 'Lobster',
#  730: 'Greek',
#  731: 'walked',
#  732: '.way',
#  733: 'location',
#  734: 'meet',
#  735: 'fuzzy',
#  736: 'steakhouse',
#  737: 'pecan',
#  738: 'affordable',
#  739: 'number',
#  740: 'else',
#  741: 'unhealthy',
#  742: 'were',
#  743: 'Kabuki',
#  744: 'auju',
#  745: 'chai',
#  746: 'workers',
#  747: 'huge',
#  748: 'drunk',
#  749: 'tender',
#  750: 'BEST',
#  751: 'Gordon',
#  752: 'MANAGEMENT',
#  753: 'extensive',
#  754: 'boys',
#  755: 'Have',
#  756: 'avoided',
#  757: 'happened',
#  758: 'yet',
#  759: 'CONCLUSION',
#  760: 'middle',
#  761: 'NO',
#  762: 'ways',
#  763: 'violinists',
#  764: 'mary',
#  765: 'assure',
#  766: 'him',
#  767: 'Shop',
#  768: 'everyone',
#  769: 'judging',
#  770: 'deliver',
#  771: 'pub',
#  772: 'alone',
#  773: '..ohhh',
#  774: 'bone',
#  775: 'meats',
#  776: '15',
#  777: 'Any',
#  778: 'pricing',
#  779: 'Sunday',
#  780: 'did',
#  781: 'fell',
#  782: 'Eve',
#  783: 'interesting',
#  784: 'promise',
#  785: '10',
#  786: 'pepper..and',
#  787: 'croutons',
#  788: 'drawing',
#  789: 'mesquite',
#  790: 'Weird',
#  791: 'grocery',
#  792: 'totally',
#  793: 'tailored',
#  794: 'opinion',
#  795: 'ensued',
#  796: 'boring',
#  797: 'Firehouse',
#  798: 'pulled',
#  799: 'mess',
#  800: 'neighborhood',
#  801: 'rubber',
#  802: 'Cape',
#  803: 'ALL',
#  804: 'These',
#  805: 'businesses',
#  806: 'winner',
#  807: 'Friend',
#  808: 'favor',
#  809: 'SCREAMS',
#  810: 'enjoyed',
#  811: 'offered',
#  812: 'callings',
#  813: 'heard',
#  814: 'gratitude',
#  815: 'mouths',
#  816: 'enjoyable',
#  817: 'Del',
#  818: 'event',
#  819: 'are',
#  820: 'Server',
#  821: 'die',
#  822: 'patty',
#  823: 'been',
#  824: 'promptly',
#  825: 'Things',
#  826: 'Terrible',
#  827: 'that',
#  828: 'recommending',
#  829: '7',
#  830: 'vinaigrette',
#  831: 'their',
#  832: 'Bean',
#  833: 'will',
#  834: 'chefs',
#  835: 'impressed',
#  836: 'Are',
#  837: 'Before',
#  838: 'via',
#  839: 'sick',
#  840: 'WHAT',
#  841: 'word',
#  842: 'Sauce',
#  843: 'charming',
#  844: 'Café',
#  845: 'hot',
#  846: 'most',
#  847: 'customize',
#  848: 'fair',
#  849: 'joint',
#  850: 'Favorite',
#  851: 'mention',
#  852: 'found',
#  853: 'guess',
#  854: 'colder',
#  855: "'ve",
#  856: 'ribeye',
#  857: 'heat',
#  858: 'front',
#  859: 'REALLY',
#  860: 'establishment',
#  861: 'hooked',
#  862: 'flair',
#  863: 'very',
#  864: 'Pho',
#  865: 'chickens',
#  866: 'really',
#  867: 'chicken',
#  868: 'imagined',
#  869: 'Nicest',
#  870: 'simply',
#  871: 'Some',
#  872: 'app',
#  873: 'biggest',
#  874: 'flirting',
#  875: 'STALE',
#  876: 'cannoli',
#  877: 'Strip',
#  878: '...',
#  879: 'inside',
#  880: 'unwelcome',
#  881: 'lost',
#  882: 'cake',
#  883: 'vomited',
#  884: 'owned',
#  885: 'bother',
#  886: 'butter',
#  887: 'done',
#  888: 'station',
#  889: 'play',
#  890: 'ended',
#  891: 'FS',
#  892: 'patio',
#  893: 'quick',
#  894: 'hardly',
#  895: 'understand',
#  896: 'old',
#  897: 'hankering',
#  898: 'may',
#  899: 'would',
#  900: 'break',
#  901: 'want',
#  902: 'FLAVOR',
#  903: 'crowds',
#  904: 'shots',
#  905: 'fast',
#  906: 'decision',
#  907: 'gyros',
#  908: 'absolute',
#  909: 'familiar',
#  910: 'fluffy',
#  911: 'warmer',
#  912: 'Reasonably',
#  913: 'similar',
#  914: 'them',
#  915: 'literally',
#  916: 'containers',
#  917: 'Luke',
#  918: 'effort',
#  919: 'Subway',
#  920: 'stinks',
#  921: 'Cartel',
#  922: 'sergeant',
#  923: 'finally',
#  924: 'preparing',
#  925: 'WAAAAAAyyyyyyyyyy',
#  926: 'noodles',
#  927: 'theft',
#  928: 'Han',
#  929: 'shops',
#  930: 'appealing',
#  931: 'cover',
#  932: 'wide',
#  933: 'fine',
#  934: "n't",
#  935: 'My',
#  936: 'wonderful',
#  937: '$',
#  938: 'cramming',
#  939: 'shall',
#  940: 'decide',
#  941: 'Service',
#  942: 'Back',
#  943: 'comfortable',
#  944: 'big',
#  945: 'selections',
#  946: 'voted',
#  947: 'rowdy',
#  948: 'please',
#  949: 'exceeding',
#  950: 'Excalibur',
#  951: 'generic',
#  952: 'otherwise',
#  953: 'eat',
#  954: 'running',
#  955: 'diverse',
#  956: 'Toast',
#  957: 'sugary',
#  958: 'time',
#  959: 'free',
#  960: 'can',
#  961: 'Dos',
#  962: 'jewel',
#  963: 'OMG',
#  964: 'friend',
#  965: 'deeply',
#  966: 'ago',
#  967: 's',
#  968: 'cool',
#  969: '3/4ths',
#  970: 'Roll',
#  971: 'oil',
#  972: 'apparently',
#  973: 'nothing',
#  974: 'Hands',
#  975: 'milkshake',
#  976: 'bill',
#  977: 'Soi',
#  978: 'cashier',
#  979: 'HAD',
#  980: 'care',
#  981: 'forty',
#  982: 'music',
#  983: 'contain',
#  984: 'Egg',
#  985: 'Owner',
#  986: 'To',
#  987: '5',
#  988: 'efficient',
#  989: 'door',
#  990: 'larger',
#  991: 'use',
#  992: 'specials',
#  993: 'iced',
#  994: 'who',
#  995: 'foot',
#  996: 'OK',
#  997: 'unexperienced',
#  998: 'peach',
#  999: 'anymore',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Will Will Will.', word_index, whole_words)
# Out:
# array([3., 0., 0., ..., 0., 0., 0.])
